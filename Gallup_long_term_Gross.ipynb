# %%
import pandas as pd
import numpy as np
import holidays
import warnings
import matplotlib.pyplot as plt
from math import sqrt
import matplotlib.dates as mdates
import pytz
import datetime
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. average model

# %% [markdown]
# ## 1.1. load data

# %%
df = pd.read_csv('data\Gallup Historical Hourly Load-2018-2020.csv')
df
# Out:
#        Year  Month   Day  period  Total Gross Load  BTM WAPA  \
# 0      2018       1    1       1             23.86      2.34
# 1      2018       1    1       2             23.46      2.34
# 2      2018       1    1       3             23.28      2.34
# 3      2018       1    1       4             23.07      2.34
# 4      2018       1    1       5             23.44      2.34
# ...     ...     ...  ...     ...               ...       ...
# 26299  2020      12   31      20             28.39      2.34
# 26300  2020      12   31      21             27.43      2.34
# 26301  2020      12   31      22             26.25      2.34
# 26302  2020      12   31      23             25.18      2.34
# 26303  2020      12   31      24             24.23      2.34
#
#        Total Net Load Serve  Unnamed: 7  Unnamed: 8  \
# 0                        22         NaN         NaN
# 1                        21         NaN         NaN
# 2                        21         NaN         NaN
# 3                        21         NaN         NaN
# 4                        21         NaN         NaN
# ...                     ...         ...         ...
# 26299                    26         NaN         NaN
# 26300                    25         NaN         NaN
# 26301                    24         NaN         NaN
# 26302                    23         NaN         NaN
# 26303                    22         NaN         NaN
#
#                                Unnamed: 9  \
# 0                        Total Gross Load
# 1                                BTM WAPA
# 2                                     NaN
# 3      Current PLEXOS Forecast Gross Flat
# 4                                     NaN
# ...                                   ...
# 26299                                 NaN
# 26300                                 NaN
# 26301                                 NaN
# 26302                                 NaN
# 26303                                 NaN
#
#                                                 Source Unnamed: 11
# 0                                    Gallup Historical         NaN
# 1      Hourly estimated based on monthly/annual energy         NaN
# 2                                                  NaN         NaN
# 3                                                  191    GWh/year
# 4                                                  NaN         NaN
# ...                                                ...         ...
# 26299                                              NaN         NaN
# 26300                                              NaN         NaN
# 26301                                              NaN         NaN
# 26302                                              NaN         NaN
# 26303                                              NaN         NaN
#
# [26304 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Month ', 'Day', 'period', 'Total Gross Load', 'BTM WAPA',
#        'Total Net Load Serve', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Source', 'Unnamed: 11'],
#       dtype='object')

# %%
df.rename(columns={'Year':'year', 'Month ':'month', 'Day':'day', 'period':'time', 'Total Gross Load':'gross_load'}, inplace=True)
df.drop(columns=['BTM WAPA','Total Net Load Serve', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9','Source', 'Unnamed: 11'], inplace=True)

# %%
df
# Out:
#        year  month  day  time  gross_load
# 0      2018      1    1     1       23.86
# 1      2018      1    1     2       23.46
# 2      2018      1    1     3       23.28
# 3      2018      1    1     4       23.07
# 4      2018      1    1     5       23.44
# ...     ...    ...  ...   ...         ...
# 26299  2020     12   31    20       28.39
# 26300  2020     12   31    21       27.43
# 26301  2020     12   31    22       26.25
# 26302  2020     12   31    23       25.18
# 26303  2020     12   31    24       24.23
#
# [26304 rows x 5 columns]

# %%
def time_convert(period):
    hour = (period - 1) % 24  # Convert period to 0-23 hour range
    return f'{hour:02d}:00:00'
# Create datetime column
df['hour_begins'] = pd.to_datetime(df[['year', 'month', 'day']].astype(str).agg('-'.join, axis=1) + ' ' + df['time'].apply(time_convert))

# %%
import matplotlib.pyplot as plt

# basic plots for actual_gross_load with x being hour_begins
plt.figure(figsize=(12, 6))
plt.plot(df['hour_begins'], df['gross_load'])
plt.title('gross_load over time')
plt.xlabel('hour_begins')
plt.ylabel('gross_load')
plt.show()

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Apply the season function to the DataFrame
df['season'] = df['month'].apply(get_season)

# %%
# Function to replace outliers within each season
def replace_outliers_with_avg_seasonal(df):
    df['gross_load_replaced'] = df['gross_load']
    for season in df['season'].unique():
        season_data = df[df['season'] == season]['gross_load']
        lower_bound = season_data.quantile(0.01)
        upper_bound = season_data.quantile(0.99)
        print(f'{season} - Lower bound: {lower_bound:.2f}, Upper bound: {upper_bound:.2f}')
        
        outliers = (df['gross_load'] < lower_bound) | (df['gross_load'] > upper_bound) | (df['gross_load'] == 0) | (df['gross_load'] == np.nan) 
        
        # Remove continuous zeros or NaNs at the end
        while pd.isna(df.iloc[-1]['gross_load_replaced']) or df.iloc[-1]['gross_load_replaced'] == 0:
            df = df.iloc[:-1]

        for idx in df[outliers].index:
            if idx == 0 or idx == len(df) - 1:
                # directly drop the first and last value
                df.at[idx, 'gross_load_replaced'] = np.nan
                continue
            # Handle edge cases where previous or next value might be NaN or zero
            prev_idx = idx - 1
            next_idx = idx + 1
            while prev_idx >= 0 and (pd.isna(df.iloc[prev_idx]['gross_load_replaced']) or df.iloc[prev_idx]['gross_load_replaced'] == 0):
                prev_idx -= 1
            while next_idx < len(df) and (pd.isna(df.iloc[next_idx]['gross_load_replaced']) or df.iloc[next_idx]['gross_load_replaced'] == 0):
                next_idx += 1
            
            if prev_idx >= 0 and next_idx < len(df):
                prev_val = df.iloc[prev_idx]['gross_load_replaced']
                next_val = df.iloc[next_idx]['gross_load_replaced']
                df.at[idx, 'gross_load_replaced'] = (prev_val + next_val) / 2
            elif prev_idx >= 0:
                df.at[idx, 'gross_load_replaced'] = df.iloc[prev_idx]['gross_load_replaced']
            elif next_idx < len(df):
                df.at[idx, 'gross_load_replaced'] = df.iloc[next_idx]['gross_load_replaced']

    return df

df = replace_outliers_with_avg_seasonal(df)

plt.figure(figsize=(16, 6))
plt.plot(df['hour_begins'], df['gross_load_replaced'], label='gross_load_replaced')
plt.xlabel('Time')
plt.ylabel('gross_load (MW)')
plt.title('Total Hourly gross_load (Replaced)')
plt.legend()

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=5))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45)

plt.show()
# Out:
# Winter - Lower bound: 17.79, Upper bound: 31.45
# Spring - Lower bound: 13.02, Upper bound: 27.22
# Summer - Lower bound: 14.43, Upper bound: 33.43
# Fall - Lower bound: 14.07, Upper bound: 29.61

# %%
df
# Out:
#        year  month  day  time  gross_load         hour_begins  season  \
# 0      2018      1    1     1       23.86 2018-01-01 00:00:00  Winter
# 1      2018      1    1     2       23.46 2018-01-01 01:00:00  Winter
# 2      2018      1    1     3       23.28 2018-01-01 02:00:00  Winter
# 3      2018      1    1     4       23.07 2018-01-01 03:00:00  Winter
# 4      2018      1    1     5       23.44 2018-01-01 04:00:00  Winter
# ...     ...    ...  ...   ...         ...                 ...     ...
# 26299  2020     12   31    20       28.39 2020-12-31 19:00:00  Winter
# 26300  2020     12   31    21       27.43 2020-12-31 20:00:00  Winter
# 26301  2020     12   31    22       26.25 2020-12-31 21:00:00  Winter
# 26302  2020     12   31    23       25.18 2020-12-31 22:00:00  Winter
# 26303  2020     12   31    24       24.23 2020-12-31 23:00:00  Winter
#
#        gross_load_replaced
# 0                    23.86
# 1                    23.46
# 2                    23.28
# 3                    23.07
# 4                    23.44
# ...                    ...
# 26299                27.75
# 26300                27.00
# 26301                26.25
# 26302                25.18
# 26303                24.23
#
# [26304 rows x 8 columns]

# %% [markdown]
# ## 1.2.feature engineering

# %%
# calculate the daily average load
df['date'] = df['hour_begins'].dt.date
daily_gross_load = df.groupby('date')['gross_load_replaced'].mean().reset_index()
daily_high = df.groupby('date')['gross_load_replaced'].max().reset_index()
daily_low = df.groupby('date')['gross_load_replaced'].min().reset_index()
daily_std = df.groupby('date')['gross_load_replaced'].std().reset_index()

daily_gross_load['daily_high'] = daily_high['gross_load_replaced']
daily_gross_load['daily_low'] = daily_low['gross_load_replaced']
daily_gross_load['daily_std'] = daily_std['gross_load_replaced']
daily_gross_load.rename(columns = {'gross_load_replaced': 'daily_avg'}, inplace = True)

# %%
import matplotlib.dates as mdates
# plot the daily average, min, max, std
plt.figure(figsize=(20, 6))
plt.plot(daily_gross_load['date'], daily_gross_load['daily_avg'], label='daily_avg')
plt.plot(daily_gross_load['date'], daily_gross_load['daily_high'], label='daily_high')
plt.plot(daily_gross_load['date'], daily_gross_load['daily_low'], label='daily_low')
plt.plot(daily_gross_load['date'], daily_gross_load['daily_std'], label='daily_std')
plt.xlabel('Date')
plt.ylabel('Actual Load (MW)')
plt.title('Daily Load')
plt.legend()

# Set date format on x-axis
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))  # set to show every 3 months
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.show()

# %%
daily_gross_load
# Out:
#             date  daily_avg  daily_high  daily_low  daily_std
# 0     2018-01-01  23.930885   26.917500      21.98   1.497397
# 1     2018-01-02  25.834857   28.714375      22.59   1.892179
# 2     2018-01-03  26.312318   28.855000      23.78   1.617253
# 3     2018-01-04  26.126016   28.778750      22.71   1.936380
# 4     2018-01-05  26.012734   28.022500      23.42   1.514981
# ...          ...        ...         ...        ...        ...
# 1091  2020-12-27  22.495833   26.920000      19.65   2.235916
# 1092  2020-12-28  23.585208   27.170000      21.09   1.992687
# 1093  2020-12-29  24.526354   28.360000      20.91   2.513542
# 1094  2020-12-30  24.223125   28.090000      19.62   2.447265
# 1095  2020-12-31  25.540000   28.070000      22.65   1.398042
#
# [1096 rows x 5 columns]

# %%
# day of the week, month, year, season vairables
daily_gross_load['date'] = pd.to_datetime(daily_gross_load['date'])
daily_gross_load['day'] = daily_gross_load['date'].dt.day
daily_gross_load['day_of_week'] = daily_gross_load['date'].dt.dayofweek
daily_gross_load['month'] = daily_gross_load['date'].dt.month
daily_gross_load['year'] = daily_gross_load['date'].dt.year
daily_gross_load['seasons'] = (daily_gross_load['month']%12 + 3)//3
seasons = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
daily_gross_load['seasons'] = daily_gross_load['seasons'].map(seasons)

# %%
daily_gross_load['month_sin'] = np.sin((daily_gross_load['month'] - 1) * (2. * np.pi / 12))
daily_gross_load['month_cos'] = np.cos((daily_gross_load['month'] - 1) * (2. * np.pi / 12))
daily_gross_load['dow_sin'] = np.sin(daily_gross_load['day_of_week'] * (2. * np.pi / 7))
daily_gross_load['dow_cos'] = np.cos(daily_gross_load['day_of_week'] * (2. * np.pi / 7))

# %%
# holiday - 0/1 binary
us_holidays = holidays.US()
daily_gross_load['holiday'] = daily_gross_load['date'].apply(lambda x: 1 if x in us_holidays else 0)

# %%
daily_gross_load.drop(columns=['daily_high','daily_low', 'daily_std'], inplace=True)
daily_gross_load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1096 non-null   datetime64[ns]
#  1   daily_avg    1096 non-null   float64
#  2   day          1096 non-null   int32
#  3   day_of_week  1096 non-null   int32
#  4   month        1096 non-null   int32
#  5   year         1096 non-null   int32
#  6   seasons      1096 non-null   object
#  7   month_sin    1096 non-null   float64
#  8   month_cos    1096 non-null   float64
#  9   dow_sin      1096 non-null   float64
#  10  dow_cos      1096 non-null   float64
#  11  holiday      1096 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(1), object(1)
# memory usage: 85.8+ KB

# %%
# print out the numerical and categorical features
numerical_features = daily_gross_load.select_dtypes(include=['float64']).columns.tolist()
categorical_features = daily_gross_load.select_dtypes(include=['datetime64[ns]', 'object', 'bool','int32','int64']).columns.tolist()
target = 'daily_avg'
numerical_features.remove(target)
print(f'Target variable: {target}')
print(f'Numerical features: {numerical_features}')
print(f'Categorical features: {categorical_features}')

# put categorical features first, numerical features last
daily_gross_load = daily_gross_load[categorical_features + numerical_features + [target]]
daily_gross_load
# Out:
# Target variable: daily_avg
# Numerical features: ['month_sin', 'month_cos', 'dow_sin', 'dow_cos']
# Categorical features: ['date', 'day', 'day_of_week', 'month', 'year', 'seasons', 'holiday']
#            date  day  day_of_week  month  year seasons  holiday  month_sin  \
# 0    2018-01-01    1            0      1  2018  Winter        1        0.0
# 1    2018-01-02    2            1      1  2018  Winter        0        0.0
# 2    2018-01-03    3            2      1  2018  Winter        0        0.0
# 3    2018-01-04    4            3      1  2018  Winter        0        0.0
# 4    2018-01-05    5            4      1  2018  Winter        0        0.0
# ...         ...  ...          ...    ...   ...     ...      ...        ...
# 1091 2020-12-27   27            6     12  2020  Winter        0       -0.5
# 1092 2020-12-28   28            0     12  2020  Winter        0       -0.5
# 1093 2020-12-29   29            1     12  2020  Winter        0       -0.5
# 1094 2020-12-30   30            2     12  2020  Winter        0       -0.5
# 1095 2020-12-31   31            3     12  2020  Winter        0       -0.5
#
#       month_cos   dow_sin   dow_cos  daily_avg
# 0      1.000000  0.000000  1.000000  23.930885
# 1      1.000000  0.781831  0.623490  25.834857
# 2      1.000000  0.974928 -0.222521  26.312318
# 3      1.000000  0.433884 -0.900969  26.126016
# 4      1.000000 -0.433884 -0.900969  26.012734
# ...         ...       ...       ...        ...
# 1091   0.866025 -0.781831  0.623490  22.495833
# 1092   0.866025  0.000000  1.000000  23.585208
# 1093   0.866025  0.781831  0.623490  24.526354
# 1094   0.866025  0.974928 -0.222521  24.223125
# 1095   0.866025  0.433884 -0.900969  25.540000
#
# [1096 rows x 12 columns]

# %%
daily_gross_load.columns
# Out:
# Index(['date', 'day', 'day_of_week', 'month', 'year', 'seasons', 'holiday',
#        'month_sin', 'month_cos', 'dow_sin', 'dow_cos', 'daily_avg'],
#       dtype='object')

# %% [markdown]
# ##  1.3. scaling and encoding

# %%
# encoding the categorical features - season only at the second column of values
daily_gross_load = pd.get_dummies(daily_gross_load, columns=['seasons'], drop_first=True) # at the last 3 columns
# Convert boolean columns to integers
for col in daily_gross_load.columns:
    if daily_gross_load[col].dtype == 'bool':
        daily_gross_load[col] = daily_gross_load[col].astype(int)
# place the target variable at the last column
daily_gross_load = daily_gross_load[[c for c in daily_gross_load if c not in ['daily_avg']] + ['daily_avg']]

# %%
daily_gross_load
# Out:
#            date  day  day_of_week  month  year  holiday  month_sin  month_cos  \
# 0    2018-01-01    1            0      1  2018        1        0.0   1.000000
# 1    2018-01-02    2            1      1  2018        0        0.0   1.000000
# 2    2018-01-03    3            2      1  2018        0        0.0   1.000000
# 3    2018-01-04    4            3      1  2018        0        0.0   1.000000
# 4    2018-01-05    5            4      1  2018        0        0.0   1.000000
# ...         ...  ...          ...    ...   ...      ...        ...        ...
# 1091 2020-12-27   27            6     12  2020        0       -0.5   0.866025
# 1092 2020-12-28   28            0     12  2020        0       -0.5   0.866025
# 1093 2020-12-29   29            1     12  2020        0       -0.5   0.866025
# 1094 2020-12-30   30            2     12  2020        0       -0.5   0.866025
# 1095 2020-12-31   31            3     12  2020        0       -0.5   0.866025
#
#        dow_sin   dow_cos  seasons_Spring  seasons_Summer  seasons_Winter  \
# 0     0.000000  1.000000               0               0               1
# 1     0.781831  0.623490               0               0               1
# 2     0.974928 -0.222521               0               0               1
# 3     0.433884 -0.900969               0               0               1
# 4    -0.433884 -0.900969               0               0               1
# ...        ...       ...             ...             ...             ...
# 1091 -0.781831  0.623490               0               0               1
# 1092  0.000000  1.000000               0               0               1
# 1093  0.781831  0.623490               0               0               1
# 1094  0.974928 -0.222521               0               0               1
# 1095  0.433884 -0.900969               0               0               1
#
#       daily_avg
# 0     23.930885
# 1     25.834857
# 2     26.312318
# 3     26.126016
# 4     26.012734
# ...         ...
# 1091  22.495833
# 1092  23.585208
# 1093  24.526354
# 1094  24.223125
# 1095  25.540000
#
# [1096 rows x 14 columns]

# %%
# scaling the columns except for the 1 column
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
daily_gross_load.iloc[:, 1:] = scaler.fit_transform(daily_gross_load.iloc[:, 1:])
daily_gross_load
# Out:
#            date       day  day_of_week  month  year  holiday  month_sin  \
# 0    2018-01-01  0.000000     0.000000    0.0   0.0        1       0.50
# 1    2018-01-02  0.033333     0.166667    0.0   0.0        0       0.50
# 2    2018-01-03  0.066667     0.333333    0.0   0.0        0       0.50
# 3    2018-01-04  0.100000     0.500000    0.0   0.0        0       0.50
# 4    2018-01-05  0.133333     0.666667    0.0   0.0        0       0.50
# ...         ...       ...          ...    ...   ...      ...        ...
# 1091 2020-12-27  0.866667     1.000000    1.0   1.0        0       0.25
# 1092 2020-12-28  0.900000     0.000000    1.0   1.0        0       0.25
# 1093 2020-12-29  0.933333     0.166667    1.0   1.0        0       0.25
# 1094 2020-12-30  0.966667     0.333333    1.0   1.0        0       0.25
# 1095 2020-12-31  1.000000     0.500000    1.0   1.0        0       0.25
#
#       month_cos   dow_sin       dow_cos  seasons_Spring  seasons_Summer  \
# 0      1.000000  0.500000  1.000000e+00               0               0
# 1      1.000000  0.900969  8.019377e-01               0               0
# 2      1.000000  1.000000  3.568959e-01               0               0
# 3      1.000000  0.722521  5.551115e-17               0               0
# 4      1.000000  0.277479  0.000000e+00               0               0
# ...         ...       ...           ...             ...             ...
# 1091   0.933013  0.099031  8.019377e-01               0               0
# 1092   0.933013  0.500000  1.000000e+00               0               0
# 1093   0.933013  0.900969  8.019377e-01               0               0
# 1094   0.933013  1.000000  3.568959e-01               0               0
# 1095   0.933013  0.722521  5.551115e-17               0               0
#
#       seasons_Winter  daily_avg
# 0                  1   0.595353
# 1                  1   0.726619
# 2                  1   0.759537
# 3                  1   0.746693
# 4                  1   0.738883
# ...              ...        ...
# 1091               1   0.496415
# 1092               1   0.571520
# 1093               1   0.636406
# 1094               1   0.615501
# 1095               1   0.706291
#
# [1096 rows x 14 columns]

# %%
# save the values of column gross_load_replaced, drop it and the attach at the last column 
gross_load_replaced = daily_gross_load['daily_avg']
daily_gross_load.drop(columns='daily_avg', inplace=True)
daily_gross_load['daily_avg'] = gross_load_replaced
daily_gross_load
# Out:
#            date       day  day_of_week  month  year  holiday  month_sin  \
# 0    2018-01-01  0.000000     0.000000    0.0   0.0        1       0.50
# 1    2018-01-02  0.033333     0.166667    0.0   0.0        0       0.50
# 2    2018-01-03  0.066667     0.333333    0.0   0.0        0       0.50
# 3    2018-01-04  0.100000     0.500000    0.0   0.0        0       0.50
# 4    2018-01-05  0.133333     0.666667    0.0   0.0        0       0.50
# ...         ...       ...          ...    ...   ...      ...        ...
# 1091 2020-12-27  0.866667     1.000000    1.0   1.0        0       0.25
# 1092 2020-12-28  0.900000     0.000000    1.0   1.0        0       0.25
# 1093 2020-12-29  0.933333     0.166667    1.0   1.0        0       0.25
# 1094 2020-12-30  0.966667     0.333333    1.0   1.0        0       0.25
# 1095 2020-12-31  1.000000     0.500000    1.0   1.0        0       0.25
#
#       month_cos   dow_sin       dow_cos  seasons_Spring  seasons_Summer  \
# 0      1.000000  0.500000  1.000000e+00               0               0
# 1      1.000000  0.900969  8.019377e-01               0               0
# 2      1.000000  1.000000  3.568959e-01               0               0
# 3      1.000000  0.722521  5.551115e-17               0               0
# 4      1.000000  0.277479  0.000000e+00               0               0
# ...         ...       ...           ...             ...             ...
# 1091   0.933013  0.099031  8.019377e-01               0               0
# 1092   0.933013  0.500000  1.000000e+00               0               0
# 1093   0.933013  0.900969  8.019377e-01               0               0
# 1094   0.933013  1.000000  3.568959e-01               0               0
# 1095   0.933013  0.722521  5.551115e-17               0               0
#
#       seasons_Winter  daily_avg
# 0                  1   0.595353
# 1                  1   0.726619
# 2                  1   0.759537
# 3                  1   0.746693
# 4                  1   0.738883
# ...              ...        ...
# 1091               1   0.496415
# 1092               1   0.571520
# 1093               1   0.636406
# 1094               1   0.615501
# 1095               1   0.706291
#
# [1096 rows x 14 columns]

# %%
daily_gross_load = daily_gross_load.dropna()
daily_gross_load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1096 non-null   datetime64[ns]
#  1   day             1096 non-null   float64
#  2   day_of_week     1096 non-null   float64
#  3   month           1096 non-null   float64
#  4   year            1096 non-null   float64
#  5   holiday         1096 non-null   int64
#  6   month_sin       1096 non-null   float64
#  7   month_cos       1096 non-null   float64
#  8   dow_sin         1096 non-null   float64
#  9   dow_cos         1096 non-null   float64
#  10  seasons_Spring  1096 non-null   int32
#  11  seasons_Summer  1096 non-null   int32
#  12  seasons_Winter  1096 non-null   int32
#  13  daily_avg       1096 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int32(3), int64(1)
# memory usage: 107.2 KB

# %% [markdown]
# ## 1.4. dividing the data into training and testing

# %%
years_of_data = len(daily_gross_load) / 365
print(f'Total years of data: {years_of_data}')
# total number of days for training and testing
print(f'Total number of days for training: {daily_gross_load.shape[0]}')
# Out:
# Total years of data: 3.0027397260273974
# Total number of days for training: 1096

# %%
daily_gross_load = daily_gross_load.sort_values(by='date')
values = daily_gross_load.drop(columns='date').values
dates = daily_gross_load['date']

# out of sample data: total length multiplies 0.3
train_days = int(values.shape[0] * 0.7)
# in sample data: the rest of the data
train = values[:train_days, :]
train_timestamps = dates[:train_days]
# print(f'start date of in sample data: {train["date"].min()}')
# print(f'end date of in sample data: {train["date"].max()}')
# print(f'length of in sample data: {train.
# shape[0]}\n')

print(f'min: {train_timestamps.min()}')
print(f'max: {train_timestamps.max()}')
print(f'length of in sample data: {train.shape[0]}\n')

test = values[train_days:, : ]
test_timestamps = dates[train_days:]
# print(f'start date of out of sample data: {test["date"].min()}')
# print(f'end date of out of sample data: {test["date"].max()}')
# print(f'length of out of sample data: {test.shape[0]}\n')

print(f'min: {test_timestamps.min()}')
print(f'max: {test_timestamps.max()}')
print(f'length of out of sample data: {test.shape[0]}')
# Out:
# min: 2018-01-01 00:00:00
# max: 2020-02-06 00:00:00
# length of in sample data: 767
#
# min: 2020-02-07 00:00:00
# max: 2020-12-31 00:00:00
# length of out of sample data: 329

# %%
# dividing the data into x and y
# x: All columns except the last,  y: The last column
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (767, 1, 12) (767,) (329, 1, 12) (329,)

# %% [markdown]
# ## 1.5. fitting the model

# %%
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, Dropout, Dense, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
# design network

# Define the model
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.3))
model.add(Dense(1, kernel_regularizer=l2(0.01)))

# Set the initial learning rate to a lower value
initial_learning_rate = 0.003
optimizer = Adam(learning_rate=initial_learning_rate)
model.compile(loss='mae', optimizer=optimizer, metrics=['mae', 'mse', 'mape'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-6)

# Fit the network
history = model.fit(train_X, train_y, epochs=300, batch_size=50, validation_data=(test_X, test_y),
                    verbose=2, shuffle=False,callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/300
# 16/16 - 1s - 55ms/step - loss: 0.3070 - mae: 0.2868 - mape: 56.8655 - mse: 0.1247 - val_loss: 0.2537 - val_mae: 0.2333 - val_mape: 2024501.7500 - val_mse: 0.0780 - learning_rate: 0.0030
# Epoch 2/300
# 16/16 - 0s - 2ms/step - loss: 0.1739 - mae: 0.1539 - mape: 41.0032 - mse: 0.0377 - val_loss: 0.2002 - val_mae: 0.1819 - val_mape: 1668937.0000 - val_mse: 0.0491 - learning_rate: 0.0030
# Epoch 3/300
# 16/16 - 0s - 2ms/step - loss: 0.1520 - mae: 0.1344 - mape: 30.9721 - mse: 0.0272 - val_loss: 0.1603 - val_mae: 0.1433 - val_mape: 1365105.0000 - val_mse: 0.0307 - learning_rate: 0.0030
# Epoch 4/300
# 16/16 - 0s - 2ms/step - loss: 0.1408 - mae: 0.1238 - mape: 29.7577 - mse: 0.0235 - val_loss: 0.1489 - val_mae: 0.1324 - val_mape: 1214637.6250 - val_mse: 0.0260 - learning_rate: 0.0030
# Epoch 5/300
# 16/16 - 0s - 4ms/step - loss: 0.1299 - mae: 0.1137 - mape: 26.5200 - mse: 0.0204 - val_loss: 0.1331 - val_mae: 0.1172 - val_mape: 1049644.7500 - val_mse: 0.0205 - learning_rate: 0.0030
# Epoch 6/300
# 16/16 - 0s - 2ms/step - loss: 0.1217 - mae: 0.1063 - mape: 24.0620 - mse: 0.0175 - val_loss: 0.1214 - val_mae: 0.1063 - val_mape: 919968.3750 - val_mse: 0.0169 - learning_rate: 0.0030
# Epoch 7/300
# 16/16 - 0s - 2ms/step - loss: 0.1170 - mae: 0.1020 - mape: 24.3688 - mse: 0.0163 - val_loss: 0.1210 - val_mae: 0.1066 - val_mape: 891717.7500 - val_mse: 0.0168 - learning_rate: 0.0030
# Epoch 8/300
# 16/16 - 0s - 2ms/step - loss: 0.1136 - mae: 0.0994 - mape: 22.7773 - mse: 0.0159 - val_loss: 0.1157 - val_mae: 0.1019 - val_mape: 801095.8750 - val_mse: 0.0153 - learning_rate: 0.0030
# Epoch 9/300
# 16/16 - 0s - 2ms/step - loss: 0.1102 - mae: 0.0966 - mape: 22.0142 - mse: 0.0152 - val_loss: 0.1136 - val_mae: 0.1003 - val_mape: 760819.5625 - val_mse: 0.0149 - learning_rate: 0.0030
# Epoch 10/300
# 16/16 - 0s - 2ms/step - loss: 0.1091 - mae: 0.0960 - mape: 21.9347 - mse: 0.0147 - val_loss: 0.1111 - val_mae: 0.0985 - val_mape: 736623.1250 - val_mse: 0.0144 - learning_rate: 0.0030
# Epoch 11/300
# 16/16 - 0s - 2ms/step - loss: 0.1084 - mae: 0.0961 - mape: 21.9254 - mse: 0.0147 - val_loss: 0.1075 - val_mae: 0.0955 - val_mape: 717122.3125 - val_mse: 0.0137 - learning_rate: 0.0030
# Epoch 12/300
# 16/16 - 0s - 2ms/step - loss: 0.1073 - mae: 0.0958 - mape: 21.6017 - mse: 0.0147 - val_loss: 0.1068 - val_mae: 0.0955 - val_mape: 724784.6875 - val_mse: 0.0138 - learning_rate: 0.0030
# Epoch 13/300
# 16/16 - 0s - 2ms/step - loss: 0.1033 - mae: 0.0921 - mape: 21.7339 - mse: 0.0136 - val_loss: 0.1028 - val_mae: 0.0923 - val_mape: 660345.7500 - val_mse: 0.0129 - learning_rate: 0.0030
# Epoch 14/300
# 16/16 - 0s - 2ms/step - loss: 0.1042 - mae: 0.0938 - mape: 21.0413 - mse: 0.0140 - val_loss: 0.1053 - val_mae: 0.0950 - val_mape: 680267.1875 - val_mse: 0.0135 - learning_rate: 0.0030
# Epoch 15/300
# 16/16 - 0s - 2ms/step - loss: 0.1016 - mae: 0.0916 - mape: 20.8787 - mse: 0.0137 - val_loss: 0.1023 - val_mae: 0.0926 - val_mape: 647266.7500 - val_mse: 0.0130 - learning_rate: 0.0030
# Epoch 16/300
# 16/16 - 0s - 2ms/step - loss: 0.1010 - mae: 0.0913 - mape: 21.2550 - mse: 0.0133 - val_loss: 0.1039 - val_mae: 0.0944 - val_mape: 664759.5625 - val_mse: 0.0134 - learning_rate: 0.0030
# Epoch 17/300
# 16/16 - 0s - 2ms/step - loss: 0.0969 - mae: 0.0877 - mape: 19.9705 - mse: 0.0122 - val_loss: 0.1003 - val_mae: 0.0913 - val_mape: 615738.8750 - val_mse: 0.0126 - learning_rate: 0.0030
# Epoch 18/300
# 16/16 - 0s - 2ms/step - loss: 0.0977 - mae: 0.0889 - mape: 20.5377 - mse: 0.0126 - val_loss: 0.1002 - val_mae: 0.0915 - val_mape: 617376.6875 - val_mse: 0.0126 - learning_rate: 0.0030
# Epoch 19/300
# 16/16 - 0s - 2ms/step - loss: 0.0968 - mae: 0.0883 - mape: 19.9403 - mse: 0.0123 - val_loss: 0.0992 - val_mae: 0.0907 - val_mape: 586633.1250 - val_mse: 0.0124 - learning_rate: 0.0030
# Epoch 20/300
# 16/16 - 0s - 2ms/step - loss: 0.0975 - mae: 0.0893 - mape: 20.0427 - mse: 0.0126 - val_loss: 0.0971 - val_mae: 0.0892 - val_mape: 565757.6250 - val_mse: 0.0120 - learning_rate: 0.0030
# Epoch 21/300
# 16/16 - 0s - 2ms/step - loss: 0.0966 - mae: 0.0888 - mape: 20.1607 - mse: 0.0126 - val_loss: 0.1004 - val_mae: 0.0927 - val_mape: 612617.8750 - val_mse: 0.0128 - learning_rate: 0.0030
# Epoch 22/300
# 16/16 - 0s - 2ms/step - loss: 0.0944 - mae: 0.0870 - mape: 19.4682 - mse: 0.0126 - val_loss: 0.0963 - val_mae: 0.0890 - val_mape: 549880.8125 - val_mse: 0.0120 - learning_rate: 0.0030
# Epoch 23/300
# 16/16 - 0s - 2ms/step - loss: 0.0934 - mae: 0.0861 - mape: 19.7797 - mse: 0.0119 - val_loss: 0.0949 - val_mae: 0.0879 - val_mape: 512809.0938 - val_mse: 0.0117 - learning_rate: 0.0030
# Epoch 24/300
# 16/16 - 0s - 2ms/step - loss: 0.0935 - mae: 0.0864 - mape: 19.3676 - mse: 0.0119 - val_loss: 0.0997 - val_mae: 0.0927 - val_mape: 553797.5625 - val_mse: 0.0126 - learning_rate: 0.0030
# Epoch 25/300
# 16/16 - 0s - 2ms/step - loss: 0.0930 - mae: 0.0864 - mape: 19.3578 - mse: 0.0117 - val_loss: 0.0993 - val_mae: 0.0927 - val_mape: 592895.4375 - val_mse: 0.0129 - learning_rate: 0.0030
# Epoch 26/300
# 16/16 - 0s - 2ms/step - loss: 0.0927 - mae: 0.0863 - mape: 19.5402 - mse: 0.0115 - val_loss: 0.0961 - val_mae: 0.0898 - val_mape: 539942.4375 - val_mse: 0.0120 - learning_rate: 0.0030
# Epoch 27/300
# 16/16 - 0s - 2ms/step - loss: 0.0887 - mae: 0.0824 - mape: 18.6872 - mse: 0.0111 - val_loss: 0.0939 - val_mae: 0.0877 - val_mape: 482244.8750 - val_mse: 0.0116 - learning_rate: 0.0030
# Epoch 28/300
# 16/16 - 0s - 2ms/step - loss: 0.0924 - mae: 0.0863 - mape: 19.2710 - mse: 0.0122 - val_loss: 0.0955 - val_mae: 0.0894 - val_mape: 493267.6562 - val_mse: 0.0119 - learning_rate: 0.0030
# Epoch 29/300
# 16/16 - 0s - 2ms/step - loss: 0.0904 - mae: 0.0846 - mape: 18.7985 - mse: 0.0113 - val_loss: 0.0945 - val_mae: 0.0887 - val_mape: 504158.5938 - val_mse: 0.0117 - learning_rate: 0.0030
# Epoch 30/300
# 16/16 - 0s - 2ms/step - loss: 0.0894 - mae: 0.0837 - mape: 18.8802 - mse: 0.0113 - val_loss: 0.0940 - val_mae: 0.0885 - val_mape: 513789.4688 - val_mse: 0.0117 - learning_rate: 0.0030
# Epoch 31/300
# 16/16 - 0s - 2ms/step - loss: 0.0885 - mae: 0.0830 - mape: 18.8627 - mse: 0.0108 - val_loss: 0.0930 - val_mae: 0.0876 - val_mape: 487627.5312 - val_mse: 0.0115 - learning_rate: 0.0030
# Epoch 32/300
# 16/16 - 0s - 2ms/step - loss: 0.0902 - mae: 0.0848 - mape: 19.2438 - mse: 0.0114 - val_loss: 0.0935 - val_mae: 0.0880 - val_mape: 480545.1250 - val_mse: 0.0116 - learning_rate: 0.0030
# Epoch 33/300
# 16/16 - 0s - 2ms/step - loss: 0.0888 - mae: 0.0835 - mape: 18.6837 - mse: 0.0110 - val_loss: 0.0933 - val_mae: 0.0880 - val_mape: 474563.0625 - val_mse: 0.0116 - learning_rate: 0.0030
# Epoch 34/300
# 16/16 - 0s - 2ms/step - loss: 0.0879 - mae: 0.0827 - mape: 18.4444 - mse: 0.0112 - val_loss: 0.0932 - val_mae: 0.0878 - val_mape: 468754.3438 - val_mse: 0.0115 - learning_rate: 0.0030
# Epoch 35/300
# 16/16 - 0s - 2ms/step - loss: 0.0870 - mae: 0.0818 - mape: 18.5807 - mse: 0.0108 - val_loss: 0.0914 - val_mae: 0.0863 - val_mape: 437618.2500 - val_mse: 0.0111 - learning_rate: 0.0030
# Epoch 36/300
# 16/16 - 0s - 2ms/step - loss: 0.0835 - mae: 0.0784 - mape: 18.0778 - mse: 0.0101 - val_loss: 0.0904 - val_mae: 0.0855 - val_mape: 420760.8125 - val_mse: 0.0110 - learning_rate: 0.0030
# Epoch 37/300
# 16/16 - 0s - 2ms/step - loss: 0.0864 - mae: 0.0816 - mape: 18.3654 - mse: 0.0109 - val_loss: 0.0931 - val_mae: 0.0882 - val_mape: 452181.7500 - val_mse: 0.0115 - learning_rate: 0.0030
# Epoch 38/300
# 16/16 - 0s - 2ms/step - loss: 0.0858 - mae: 0.0812 - mape: 18.2494 - mse: 0.0106 - val_loss: 0.0928 - val_mae: 0.0881 - val_mape: 449759.1875 - val_mse: 0.0115 - learning_rate: 0.0030
# Epoch 39/300
# 16/16 - 0s - 2ms/step - loss: 0.0863 - mae: 0.0818 - mape: 18.1308 - mse: 0.0108 - val_loss: 0.0917 - val_mae: 0.0874 - val_mape: 446580.5625 - val_mse: 0.0114 - learning_rate: 0.0030
# Epoch 40/300
# 16/16 - 0s - 2ms/step - loss: 0.0839 - mae: 0.0795 - mape: 18.1302 - mse: 0.0104 - val_loss: 0.0903 - val_mae: 0.0859 - val_mape: 417771.4688 - val_mse: 0.0111 - learning_rate: 0.0030
# Epoch 41/300
# 16/16 - 0s - 2ms/step - loss: 0.0847 - mae: 0.0804 - mape: 17.9634 - mse: 0.0104 - val_loss: 0.0916 - val_mae: 0.0873 - val_mape: 435143.7812 - val_mse: 0.0113 - learning_rate: 0.0030
# Epoch 42/300
# 16/16 - 0s - 2ms/step - loss: 0.0846 - mae: 0.0803 - mape: 18.3732 - mse: 0.0102 - val_loss: 0.0906 - val_mae: 0.0863 - val_mape: 414405.8750 - val_mse: 0.0111 - learning_rate: 0.0030
# Epoch 43/300
# 16/16 - 0s - 2ms/step - loss: 0.0836 - mae: 0.0795 - mape: 17.8213 - mse: 0.0102 - val_loss: 0.0905 - val_mae: 0.0864 - val_mape: 419451.0938 - val_mse: 0.0111 - learning_rate: 0.0030
# Epoch 44/300
# 16/16 - 0s - 2ms/step - loss: 0.0832 - mae: 0.0792 - mape: 18.0305 - mse: 0.0101 - val_loss: 0.0909 - val_mae: 0.0868 - val_mape: 435024.1875 - val_mse: 0.0112 - learning_rate: 0.0030
# Epoch 45/300
# 16/16 - 0s - 2ms/step - loss: 0.0831 - mae: 0.0791 - mape: 17.9610 - mse: 0.0103 - val_loss: 0.0891 - val_mae: 0.0851 - val_mape: 391415.7500 - val_mse: 0.0108 - learning_rate: 0.0030
# Epoch 46/300
# 16/16 - 0s - 2ms/step - loss: 0.0835 - mae: 0.0795 - mape: 18.1078 - mse: 0.0103 - val_loss: 0.0891 - val_mae: 0.0851 - val_mape: 394860.1875 - val_mse: 0.0108 - learning_rate: 0.0030
# Epoch 47/300
# 16/16 - 0s - 2ms/step - loss: 0.0850 - mae: 0.0811 - mape: 18.2241 - mse: 0.0105 - val_loss: 0.0877 - val_mae: 0.0838 - val_mape: 372903.2812 - val_mse: 0.0105 - learning_rate: 0.0030
# Epoch 48/300
# 16/16 - 0s - 2ms/step - loss: 0.0839 - mae: 0.0801 - mape: 18.5294 - mse: 0.0104 - val_loss: 0.0871 - val_mae: 0.0832 - val_mape: 347313.5938 - val_mse: 0.0104 - learning_rate: 0.0030
# Epoch 49/300
# 16/16 - 0s - 2ms/step - loss: 0.0847 - mae: 0.0809 - mape: 18.0726 - mse: 0.0104 - val_loss: 0.0872 - val_mae: 0.0833 - val_mape: 346152.6250 - val_mse: 0.0104 - learning_rate: 0.0030
# Epoch 50/300
# 16/16 - 0s - 2ms/step - loss: 0.0830 - mae: 0.0794 - mape: 17.6694 - mse: 0.0105 - val_loss: 0.0879 - val_mae: 0.0843 - val_mape: 356119.6250 - val_mse: 0.0105 - learning_rate: 0.0030
# Epoch 51/300
# 16/16 - 0s - 2ms/step - loss: 0.0815 - mae: 0.0778 - mape: 17.9925 - mse: 0.0100 - val_loss: 0.0865 - val_mae: 0.0829 - val_mape: 308542.3125 - val_mse: 0.0103 - learning_rate: 0.0030
# Epoch 52/300
# 16/16 - 0s - 2ms/step - loss: 0.0828 - mae: 0.0792 - mape: 17.9654 - mse: 0.0103 - val_loss: 0.0863 - val_mae: 0.0826 - val_mape: 297338.7500 - val_mse: 0.0103 - learning_rate: 0.0030
# Epoch 53/300
# 16/16 - 0s - 2ms/step - loss: 0.0818 - mae: 0.0784 - mape: 17.1437 - mse: 0.0099 - val_loss: 0.0880 - val_mae: 0.0845 - val_mape: 340356.0938 - val_mse: 0.0106 - learning_rate: 0.0030
# Epoch 54/300
# 16/16 - 0s - 2ms/step - loss: 0.0826 - mae: 0.0792 - mape: 18.0827 - mse: 0.0101 - val_loss: 0.0866 - val_mae: 0.0832 - val_mape: 303569.5938 - val_mse: 0.0103 - learning_rate: 0.0030
# Epoch 55/300
# 16/16 - 0s - 2ms/step - loss: 0.0789 - mae: 0.0754 - mape: 16.9523 - mse: 0.0093 - val_loss: 0.0850 - val_mae: 0.0815 - val_mape: 260985.7812 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 56/300
# 16/16 - 0s - 2ms/step - loss: 0.0812 - mae: 0.0778 - mape: 17.2017 - mse: 0.0100 - val_loss: 0.0856 - val_mae: 0.0822 - val_mape: 282443.1562 - val_mse: 0.0102 - learning_rate: 0.0030
# Epoch 57/300
# 16/16 - 0s - 2ms/step - loss: 0.0807 - mae: 0.0775 - mape: 17.5315 - mse: 0.0095 - val_loss: 0.0870 - val_mae: 0.0836 - val_mape: 315707.1250 - val_mse: 0.0104 - learning_rate: 0.0030
# Epoch 58/300
# 16/16 - 0s - 2ms/step - loss: 0.0813 - mae: 0.0781 - mape: 17.7746 - mse: 0.0097 - val_loss: 0.0864 - val_mae: 0.0831 - val_mape: 299813.3125 - val_mse: 0.0103 - learning_rate: 0.0030
# Epoch 59/300
# 16/16 - 0s - 4ms/step - loss: 0.0823 - mae: 0.0792 - mape: 17.7733 - mse: 0.0099 - val_loss: 0.0857 - val_mae: 0.0825 - val_mape: 279743.1250 - val_mse: 0.0103 - learning_rate: 0.0030
# Epoch 60/300
# 16/16 - 0s - 2ms/step - loss: 0.0815 - mae: 0.0784 - mape: 17.8044 - mse: 0.0099 - val_loss: 0.0844 - val_mae: 0.0812 - val_mape: 249442.7969 - val_mse: 0.0100 - learning_rate: 0.0030
# Epoch 61/300
# 16/16 - 0s - 2ms/step - loss: 0.0810 - mae: 0.0780 - mape: 17.3446 - mse: 0.0100 - val_loss: 0.0853 - val_mae: 0.0821 - val_mape: 280163.9062 - val_mse: 0.0102 - learning_rate: 0.0030
# Epoch 62/300
# 16/16 - 0s - 2ms/step - loss: 0.0815 - mae: 0.0785 - mape: 17.5159 - mse: 0.0100 - val_loss: 0.0846 - val_mae: 0.0816 - val_mape: 261080.8438 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 63/300
# 16/16 - 0s - 2ms/step - loss: 0.0805 - mae: 0.0776 - mape: 17.4093 - mse: 0.0097 - val_loss: 0.0865 - val_mae: 0.0835 - val_mape: 305889.2500 - val_mse: 0.0104 - learning_rate: 0.0030
# Epoch 64/300
# 16/16 - 0s - 2ms/step - loss: 0.0780 - mae: 0.0752 - mape: 16.9707 - mse: 0.0094 - val_loss: 0.0859 - val_mae: 0.0830 - val_mape: 277393.0312 - val_mse: 0.0104 - learning_rate: 0.0030
# Epoch 65/300
# 16/16 - 0s - 2ms/step - loss: 0.0785 - mae: 0.0756 - mape: 16.8524 - mse: 0.0094 - val_loss: 0.0845 - val_mae: 0.0815 - val_mape: 221408.0938 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 66/300
# 16/16 - 0s - 2ms/step - loss: 0.0816 - mae: 0.0788 - mape: 17.0966 - mse: 0.0102 - val_loss: 0.0850 - val_mae: 0.0820 - val_mape: 237952.2500 - val_mse: 0.0102 - learning_rate: 0.0030
# Epoch 67/300
# 16/16 - 0s - 2ms/step - loss: 0.0795 - mae: 0.0767 - mape: 17.2738 - mse: 0.0095 - val_loss: 0.0845 - val_mae: 0.0816 - val_mape: 244385.8281 - val_mse: 0.0100 - learning_rate: 0.0030
# Epoch 68/300
# 16/16 - 0s - 2ms/step - loss: 0.0803 - mae: 0.0776 - mape: 17.4483 - mse: 0.0097 - val_loss: 0.0844 - val_mae: 0.0816 - val_mape: 246889.8750 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 69/300
# 16/16 - 0s - 2ms/step - loss: 0.0805 - mae: 0.0778 - mape: 17.1607 - mse: 0.0099 - val_loss: 0.0848 - val_mae: 0.0820 - val_mape: 259915.2031 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 70/300
# 16/16 - 0s - 2ms/step - loss: 0.0795 - mae: 0.0769 - mape: 17.2306 - mse: 0.0098 - val_loss: 0.0845 - val_mae: 0.0818 - val_mape: 240524.8438 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 71/300
# 16/16 - 0s - 2ms/step - loss: 0.0784 - mae: 0.0757 - mape: 16.9762 - mse: 0.0093 - val_loss: 0.0836 - val_mae: 0.0808 - val_mape: 208353.6562 - val_mse: 0.0099 - learning_rate: 0.0030
# Epoch 72/300
# 16/16 - 0s - 2ms/step - loss: 0.0787 - mae: 0.0760 - mape: 17.2661 - mse: 0.0094 - val_loss: 0.0834 - val_mae: 0.0807 - val_mape: 204926.5156 - val_mse: 0.0099 - learning_rate: 0.0030
# Epoch 73/300
# 16/16 - 0s - 2ms/step - loss: 0.0793 - mae: 0.0767 - mape: 16.8440 - mse: 0.0096 - val_loss: 0.0838 - val_mae: 0.0810 - val_mape: 195018.2812 - val_mse: 0.0100 - learning_rate: 0.0030
# Epoch 74/300
# 16/16 - 0s - 2ms/step - loss: 0.0787 - mae: 0.0761 - mape: 16.6392 - mse: 0.0095 - val_loss: 0.0840 - val_mae: 0.0813 - val_mape: 216327.8750 - val_mse: 0.0100 - learning_rate: 0.0030
# Epoch 75/300
# 16/16 - 0s - 2ms/step - loss: 0.0782 - mae: 0.0757 - mape: 17.1621 - mse: 0.0095 - val_loss: 0.0839 - val_mae: 0.0813 - val_mape: 234721.3125 - val_mse: 0.0099 - learning_rate: 0.0030
# Epoch 76/300
# 16/16 - 0s - 2ms/step - loss: 0.0804 - mae: 0.0779 - mape: 17.5653 - mse: 0.0099 - val_loss: 0.0828 - val_mae: 0.0803 - val_mape: 193424.9844 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 77/300
# 16/16 - 0s - 2ms/step - loss: 0.0769 - mae: 0.0744 - mape: 16.6541 - mse: 0.0089 - val_loss: 0.0834 - val_mae: 0.0808 - val_mape: 233150.4688 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 78/300
# 16/16 - 0s - 2ms/step - loss: 0.0771 - mae: 0.0747 - mape: 16.6667 - mse: 0.0093 - val_loss: 0.0843 - val_mae: 0.0818 - val_mape: 268488.1562 - val_mse: 0.0100 - learning_rate: 0.0030
# Epoch 79/300
# 16/16 - 0s - 2ms/step - loss: 0.0776 - mae: 0.0752 - mape: 17.1628 - mse: 0.0092 - val_loss: 0.0834 - val_mae: 0.0809 - val_mape: 226553.9219 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 80/300
# 16/16 - 0s - 2ms/step - loss: 0.0771 - mae: 0.0746 - mape: 16.8067 - mse: 0.0092 - val_loss: 0.0832 - val_mae: 0.0807 - val_mape: 207084.2969 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 81/300
# 16/16 - 0s - 2ms/step - loss: 0.0777 - mae: 0.0753 - mape: 16.9513 - mse: 0.0093 - val_loss: 0.0831 - val_mae: 0.0807 - val_mape: 214478.5469 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 82/300
# 16/16 - 0s - 2ms/step - loss: 0.0771 - mae: 0.0747 - mape: 16.9695 - mse: 0.0092 - val_loss: 0.0822 - val_mae: 0.0797 - val_mape: 155747.7656 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 83/300
# 16/16 - 0s - 2ms/step - loss: 0.0769 - mae: 0.0745 - mape: 16.4069 - mse: 0.0093 - val_loss: 0.0829 - val_mae: 0.0804 - val_mape: 166037.0625 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 84/300
# 16/16 - 0s - 2ms/step - loss: 0.0763 - mae: 0.0740 - mape: 16.7835 - mse: 0.0090 - val_loss: 0.0840 - val_mae: 0.0816 - val_mape: 226069.4531 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 85/300
# 16/16 - 0s - 2ms/step - loss: 0.0789 - mae: 0.0767 - mape: 16.7556 - mse: 0.0095 - val_loss: 0.0846 - val_mae: 0.0823 - val_mape: 253493.0156 - val_mse: 0.0101 - learning_rate: 0.0030
# Epoch 86/300
# 16/16 - 0s - 2ms/step - loss: 0.0759 - mae: 0.0736 - mape: 16.9135 - mse: 0.0090 - val_loss: 0.0823 - val_mae: 0.0800 - val_mape: 178344.2188 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 87/300
# 16/16 - 0s - 2ms/step - loss: 0.0776 - mae: 0.0753 - mape: 16.8708 - mse: 0.0093 - val_loss: 0.0827 - val_mae: 0.0802 - val_mape: 182692.0156 - val_mse: 0.0097 - learning_rate: 0.0030
# Epoch 88/300
# 16/16 - 0s - 2ms/step - loss: 0.0773 - mae: 0.0750 - mape: 16.3723 - mse: 0.0092 - val_loss: 0.0824 - val_mae: 0.0801 - val_mape: 133163.0938 - val_mse: 0.0097 - learning_rate: 0.0030
# Epoch 89/300
# 16/16 - 0s - 2ms/step - loss: 0.0772 - mae: 0.0748 - mape: 16.8437 - mse: 0.0091 - val_loss: 0.0819 - val_mae: 0.0795 - val_mape: 102370.2109 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 90/300
# 16/16 - 0s - 2ms/step - loss: 0.0784 - mae: 0.0761 - mape: 16.5394 - mse: 0.0094 - val_loss: 0.0830 - val_mae: 0.0806 - val_mape: 199811.4375 - val_mse: 0.0098 - learning_rate: 0.0030
# Epoch 91/300
# 16/16 - 0s - 2ms/step - loss: 0.0780 - mae: 0.0759 - mape: 17.0604 - mse: 0.0095 - val_loss: 0.0831 - val_mae: 0.0810 - val_mape: 192088.8906 - val_mse: 0.0097 - learning_rate: 0.0030
# Epoch 92/300
# 16/16 - 0s - 2ms/step - loss: 0.0751 - mae: 0.0729 - mape: 16.5557 - mse: 0.0088 - val_loss: 0.0820 - val_mae: 0.0797 - val_mape: 165435.7344 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 93/300
# 16/16 - 0s - 2ms/step - loss: 0.0762 - mae: 0.0739 - mape: 16.7848 - mse: 0.0091 - val_loss: 0.0820 - val_mae: 0.0797 - val_mape: 155895.3281 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 94/300
# 16/16 - 0s - 2ms/step - loss: 0.0758 - mae: 0.0736 - mape: 16.5888 - mse: 0.0089 - val_loss: 0.0826 - val_mae: 0.0804 - val_mape: 181441.3594 - val_mse: 0.0097 - learning_rate: 0.0030
# Epoch 95/300
# 16/16 - 0s - 2ms/step - loss: 0.0778 - mae: 0.0756 - mape: 16.7874 - mse: 0.0092 - val_loss: 0.0826 - val_mae: 0.0803 - val_mape: 188007.1719 - val_mse: 0.0097 - learning_rate: 0.0030
# Epoch 96/300
# 16/16 - 0s - 2ms/step - loss: 0.0774 - mae: 0.0753 - mape: 17.0389 - mse: 0.0094 - val_loss: 0.0820 - val_mae: 0.0798 - val_mape: 190757.5625 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 97/300
# 16/16 - 0s - 2ms/step - loss: 0.0750 - mae: 0.0729 - mape: 16.3658 - mse: 0.0089 - val_loss: 0.0817 - val_mae: 0.0796 - val_mape: 177560.1094 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 98/300
# 16/16 - 0s - 2ms/step - loss: 0.0749 - mae: 0.0728 - mape: 16.5184 - mse: 0.0087 - val_loss: 0.0818 - val_mae: 0.0796 - val_mape: 168195.9062 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 99/300
# 16/16 - 0s - 2ms/step - loss: 0.0754 - mae: 0.0733 - mape: 16.3858 - mse: 0.0088 - val_loss: 0.0824 - val_mae: 0.0802 - val_mape: 189087.9375 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 100/300
# 16/16 - 0s - 2ms/step - loss: 0.0772 - mae: 0.0751 - mape: 16.8733 - mse: 0.0092 - val_loss: 0.0818 - val_mae: 0.0797 - val_mape: 164075.7188 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 101/300
# 16/16 - 0s - 2ms/step - loss: 0.0759 - mae: 0.0738 - mape: 16.6739 - mse: 0.0089 - val_loss: 0.0820 - val_mae: 0.0798 - val_mape: 181090.9844 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 102/300
# 16/16 - 0s - 2ms/step - loss: 0.0743 - mae: 0.0723 - mape: 15.8933 - mse: 0.0087 - val_loss: 0.0818 - val_mae: 0.0797 - val_mape: 170657.1719 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 103/300
# 16/16 - 0s - 2ms/step - loss: 0.0755 - mae: 0.0735 - mape: 16.2765 - mse: 0.0089 - val_loss: 0.0821 - val_mae: 0.0800 - val_mape: 182680.7188 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 104/300
# 16/16 - 0s - 2ms/step - loss: 0.0753 - mae: 0.0733 - mape: 16.6783 - mse: 0.0087 - val_loss: 0.0812 - val_mae: 0.0791 - val_mape: 159059.1562 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 105/300
# 16/16 - 0s - 2ms/step - loss: 0.0771 - mae: 0.0751 - mape: 16.6163 - mse: 0.0093 - val_loss: 0.0809 - val_mae: 0.0787 - val_mape: 159365.7656 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 106/300
# 16/16 - 0s - 2ms/step - loss: 0.0760 - mae: 0.0739 - mape: 16.6006 - mse: 0.0093 - val_loss: 0.0811 - val_mae: 0.0790 - val_mape: 97516.4609 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 107/300
# 16/16 - 0s - 2ms/step - loss: 0.0768 - mae: 0.0747 - mape: 16.4425 - mse: 0.0090 - val_loss: 0.0811 - val_mae: 0.0789 - val_mape: 111838.9531 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 108/300
# 16/16 - 0s - 2ms/step - loss: 0.0759 - mae: 0.0738 - mape: 16.1867 - mse: 0.0090 - val_loss: 0.0822 - val_mae: 0.0802 - val_mape: 180872.9375 - val_mse: 0.0096 - learning_rate: 0.0030
# Epoch 109/300
# 16/16 - 0s - 2ms/step - loss: 0.0757 - mae: 0.0737 - mape: 16.9415 - mse: 0.0090 - val_loss: 0.0811 - val_mae: 0.0790 - val_mape: 118068.1953 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 110/300
# 16/16 - 0s - 2ms/step - loss: 0.0757 - mae: 0.0737 - mape: 16.2442 - mse: 0.0088 - val_loss: 0.0809 - val_mae: 0.0789 - val_mape: 115005.6562 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 111/300
# 16/16 - 0s - 2ms/step - loss: 0.0756 - mae: 0.0737 - mape: 16.5292 - mse: 0.0089 - val_loss: 0.0814 - val_mae: 0.0795 - val_mape: 171646.1719 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 112/300
# 16/16 - 0s - 2ms/step - loss: 0.0729 - mae: 0.0710 - mape: 16.0818 - mse: 0.0085 - val_loss: 0.0804 - val_mae: 0.0783 - val_mape: 105802.3828 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 113/300
# 16/16 - 0s - 2ms/step - loss: 0.0762 - mae: 0.0742 - mape: 16.5327 - mse: 0.0090 - val_loss: 0.0808 - val_mae: 0.0787 - val_mape: 121278.0703 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 114/300
# 16/16 - 0s - 2ms/step - loss: 0.0761 - mae: 0.0742 - mape: 16.8743 - mse: 0.0090 - val_loss: 0.0811 - val_mae: 0.0792 - val_mape: 166408.4062 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 115/300
# 16/16 - 0s - 2ms/step - loss: 0.0735 - mae: 0.0716 - mape: 16.3056 - mse: 0.0086 - val_loss: 0.0800 - val_mae: 0.0780 - val_mape: 112762.5781 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 116/300
# 16/16 - 0s - 2ms/step - loss: 0.0743 - mae: 0.0724 - mape: 16.1144 - mse: 0.0087 - val_loss: 0.0801 - val_mae: 0.0781 - val_mape: 98874.7891 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 117/300
# 16/16 - 0s - 2ms/step - loss: 0.0745 - mae: 0.0726 - mape: 16.4054 - mse: 0.0087 - val_loss: 0.0815 - val_mae: 0.0796 - val_mape: 183979.8594 - val_mse: 0.0095 - learning_rate: 0.0030
# Epoch 118/300
# 16/16 - 0s - 2ms/step - loss: 0.0749 - mae: 0.0731 - mape: 16.3665 - mse: 0.0087 - val_loss: 0.0806 - val_mae: 0.0786 - val_mape: 82542.0938 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 119/300
# 16/16 - 0s - 2ms/step - loss: 0.0748 - mae: 0.0728 - mape: 16.4397 - mse: 0.0087 - val_loss: 0.0804 - val_mae: 0.0785 - val_mape: 126554.4297 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 120/300
# 16/16 - 0s - 2ms/step - loss: 0.0736 - mae: 0.0718 - mape: 16.0606 - mse: 0.0086 - val_loss: 0.0808 - val_mae: 0.0790 - val_mape: 154258.6562 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 121/300
# 16/16 - 0s - 2ms/step - loss: 0.0738 - mae: 0.0719 - mape: 16.0476 - mse: 0.0086 - val_loss: 0.0803 - val_mae: 0.0783 - val_mape: 112522.8906 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 122/300
# 16/16 - 0s - 2ms/step - loss: 0.0738 - mae: 0.0719 - mape: 16.1647 - mse: 0.0087 - val_loss: 0.0811 - val_mae: 0.0792 - val_mape: 62883.3555 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 123/300
# 16/16 - 0s - 2ms/step - loss: 0.0752 - mae: 0.0733 - mape: 15.9709 - mse: 0.0087 - val_loss: 0.0812 - val_mae: 0.0792 - val_mape: 101103.3672 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 124/300
# 16/16 - 0s - 2ms/step - loss: 0.0735 - mae: 0.0716 - mape: 16.0400 - mse: 0.0087 - val_loss: 0.0806 - val_mae: 0.0787 - val_mape: 104230.3203 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 125/300
# 16/16 - 0s - 2ms/step - loss: 0.0730 - mae: 0.0711 - mape: 15.7534 - mse: 0.0084 - val_loss: 0.0814 - val_mae: 0.0794 - val_mape: 64423.0938 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 126/300
# 16/16 - 0s - 2ms/step - loss: 0.0739 - mae: 0.0720 - mape: 15.7824 - mse: 0.0086 - val_loss: 0.0814 - val_mae: 0.0795 - val_mape: 114453.6875 - val_mse: 0.0094 - learning_rate: 0.0030
# Epoch 127/300
# 16/16 - 0s - 4ms/step - loss: 0.0742 - mae: 0.0724 - mape: 16.2345 - mse: 0.0086 - val_loss: 0.0807 - val_mae: 0.0788 - val_mape: 71236.3516 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 128/300
# 16/16 - 0s - 2ms/step - loss: 0.0742 - mae: 0.0722 - mape: 16.4020 - mse: 0.0087 - val_loss: 0.0800 - val_mae: 0.0781 - val_mape: 37489.9531 - val_mse: 0.0092 - learning_rate: 0.0030
# Epoch 129/300
# 16/16 - 0s - 2ms/step - loss: 0.0747 - mae: 0.0729 - mape: 16.1509 - mse: 0.0087 - val_loss: 0.0808 - val_mae: 0.0789 - val_mape: 168986.9375 - val_mse: 0.0093 - learning_rate: 0.0030
# Epoch 130/300
# 16/16 - 0s - 2ms/step - loss: 0.0753 - mae: 0.0736 - mape: 16.3021 - mse: 0.0088 - val_loss: 0.0810 - val_mae: 0.0792 - val_mape: 164332.6719 - val_mse: 0.0093 - learning_rate: 0.0030

# %%
# Plot history for loss, MAE, and RMSE as before
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['mae'], label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('Mean Absolute Error (MAE)')
plt.show()

train_rmse = np.sqrt(history.history['mse'])
val_rmse = np.sqrt(history.history['val_mse'])
plt.figure(figsize=(12, 6))
plt.plot(train_rmse, label='train_rmse')
plt.plot(val_rmse, label='val_rmse')
plt.xlabel('Epochs')
plt.ylabel('RMSE')
plt.legend()
plt.title('Root Mean Squared Error (RMSE)')
plt.show()

# %%
# Calculate MAPE manually, handling zero values
def safe_mape(y_true, y_pred, epsilon=1e-10):
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / (y_true[mask] + epsilon))) * 100

train_predictions = model.predict(train_X)
train_X_reshaped = train_X.reshape((train_X.shape[0], train_X.shape[2]))
# Invert scaling for forecast
inv_yhat = np.concatenate((train_X_reshaped,train_predictions), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, -1]
# Invert scaling for actual
train_y_reshaped = train_y.reshape((len(train_y), 1))
inv_y = np.concatenate((train_X_reshaped, train_y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, -1]
# Calculate RMSE, MAE, MAPE
train_rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
train_mae = mean_absolute_error(inv_y, inv_yhat)
train_mape = np.mean(np.abs((inv_y - inv_yhat) / inv_y)) * 100


test_predictions = model.predict(test_X)
# Reshape test_X for inverse scaling
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# Invert scaling for forecast
inv_yhat = np.concatenate((test_X_reshaped,test_predictions), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, -1]
# Invert scaling for actual
test_y_reshaped = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_X_reshaped, test_y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, -1]
# Calculate RMSE, MAE, MAPE
test_rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
test_mae = mean_absolute_error(inv_y, inv_yhat)
test_mape = np.mean(np.abs((inv_y - inv_yhat) / inv_y)) * 100


print(f"Train RMSE: {train_rmse:.3f}")
print(f"Train MAE: {train_mae:.3f}")
print(f"Train MAPE: {train_mape:.3f}%")
print(f"\nTest RMSE: {test_rmse:.3f}")
print(f"Test MAE: {test_mae:.3f}")
print(f"Test MAPE: {test_mape:.3f}%")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# Train RMSE: 1.293
# Train MAE: 0.998
# Train MAPE: 4.426%
#
# Test RMSE: 1.390
# Test MAE: 1.131
# Test MAPE: 5.557%

# %% [markdown]
# ## 1.6. prediction plot

# %%
# Extract the test data with timestamps
test_df = daily_gross_load.iloc[train_days:, :].copy()
test_df['date'] = daily_gross_load.iloc[train_days:]['date']

# Identify gaps in the data
actual_vs_predicted = pd.DataFrame({
    'date': test_timestamps,
    'actual': inv_y,
    'predicted': inv_yhat
})

# Check for gaps in the timestamps (in days)
actual_vs_predicted['date_diff'] = actual_vs_predicted['date'].diff().dt.days
gaps = actual_vs_predicted[actual_vs_predicted['date_diff'] > 1]

# Plot actual vs predicted values with gaps highlighted
plt.figure(figsize=(20, 6))
plt.plot(actual_vs_predicted['date'], actual_vs_predicted['actual'], label='Actual', color='blue')
plt.plot(actual_vs_predicted['date'], actual_vs_predicted['predicted'], label='Predicted', color='orange')
for gap_start in gaps['date']:
    plt.axvline(x=gap_start, color='red', linestyle='--', alpha=0.5)
plt.title('Actual vs Predicted Values with Gaps Highlighted')
plt.xlabel('Time')
plt.ylabel('Values (MW)')
plt.legend()
plt.grid(True)

# Set date format on x-axis every 15 days
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=25))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.xticks(rotation=45)
plt.show()

# Print the gaps and their nearest significant time differences
print("Gaps in data:")
for index, row in gaps.iterrows():
    previous_timestamp = row['date'] - pd.Timedelta(days=row['date_diff'])
    next_timestamp = row['date'] + pd.Timedelta(days=row['date_diff'])

    previous_row = actual_vs_predicted[actual_vs_predicted['date'] == previous_timestamp]
    next_row = actual_vs_predicted[actual_vs_predicted['date'] == next_timestamp]

    gap_start = previous_row['date'].values[0] if not previous_row.empty else 'N/A'
    gap_end = row['date']

    print(f"Gap Start: {pd.to_datetime(gap_start).strftime('%Y-%m-%d') if gap_start != 'N/A' else 'N/A'}")
    print(f"Gap ends at: {gap_end.strftime('%Y-%m-%d')}")
    print(f"Time Difference: {row['date_diff']} days\n")
# Out:
# Gaps in data:

# %% [markdown]
# # 2. sumup model

# %% [markdown]
# ## 2.1. load data

# %%
df = pd.read_csv('data\Gallup Historical Hourly Load-2018-2020.csv')
df
# Out:
#        Year  Month   Day  period  Total Gross Load  BTM WAPA  \
# 0      2018       1    1       1             23.86      2.34
# 1      2018       1    1       2             23.46      2.34
# 2      2018       1    1       3             23.28      2.34
# 3      2018       1    1       4             23.07      2.34
# 4      2018       1    1       5             23.44      2.34
# ...     ...     ...  ...     ...               ...       ...
# 26299  2020      12   31      20             28.39      2.34
# 26300  2020      12   31      21             27.43      2.34
# 26301  2020      12   31      22             26.25      2.34
# 26302  2020      12   31      23             25.18      2.34
# 26303  2020      12   31      24             24.23      2.34
#
#        Total Net Load Serve  Unnamed: 7  Unnamed: 8  \
# 0                        22         NaN         NaN
# 1                        21         NaN         NaN
# 2                        21         NaN         NaN
# 3                        21         NaN         NaN
# 4                        21         NaN         NaN
# ...                     ...         ...         ...
# 26299                    26         NaN         NaN
# 26300                    25         NaN         NaN
# 26301                    24         NaN         NaN
# 26302                    23         NaN         NaN
# 26303                    22         NaN         NaN
#
#                                Unnamed: 9  \
# 0                        Total Gross Load
# 1                                BTM WAPA
# 2                                     NaN
# 3      Current PLEXOS Forecast Gross Flat
# 4                                     NaN
# ...                                   ...
# 26299                                 NaN
# 26300                                 NaN
# 26301                                 NaN
# 26302                                 NaN
# 26303                                 NaN
#
#                                                 Source Unnamed: 11
# 0                                    Gallup Historical         NaN
# 1      Hourly estimated based on monthly/annual energy         NaN
# 2                                                  NaN         NaN
# 3                                                  191    GWh/year
# 4                                                  NaN         NaN
# ...                                                ...         ...
# 26299                                              NaN         NaN
# 26300                                              NaN         NaN
# 26301                                              NaN         NaN
# 26302                                              NaN         NaN
# 26303                                              NaN         NaN
#
# [26304 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Month ', 'Day', 'period', 'Total Gross Load', 'BTM WAPA',
#        'Total Net Load Serve', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Source', 'Unnamed: 11'],
#       dtype='object')

# %%
df.rename(columns={'Year':'year', 'Month ':'month', 'Day':'day', 'period':'time', 'Total Gross Load':'gross_load'}, inplace=True)
df.drop(columns=['BTM WAPA','Total Net Load Serve', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9','Source', 'Unnamed: 11'], inplace=True)

# %%
df
# Out:
#        year  month  day  time  gross_load
# 0      2018      1    1     1       23.86
# 1      2018      1    1     2       23.46
# 2      2018      1    1     3       23.28
# 3      2018      1    1     4       23.07
# 4      2018      1    1     5       23.44
# ...     ...    ...  ...   ...         ...
# 26299  2020     12   31    20       28.39
# 26300  2020     12   31    21       27.43
# 26301  2020     12   31    22       26.25
# 26302  2020     12   31    23       25.18
# 26303  2020     12   31    24       24.23
#
# [26304 rows x 5 columns]

# %%
def time_convert(period):
    hour = (period - 1) % 24  # Convert period to 0-23 hour range
    return f'{hour:02d}:00:00'
# Create datetime column
df['hour_begins'] = pd.to_datetime(df[['year', 'month', 'day']].astype(str).agg('-'.join, axis=1) + ' ' + df['time'].apply(time_convert))

# %%
# calculate the daily accumulation of the load (gross_load_replaced)
df['date_begins'] = df['hour_begins'].dt.date
daily_accumulation_ = df.groupby('date_begins')['gross_load'].sum().reset_index()
daily_accumulation_.rename(columns = {'gross_load': 'daily_accumulation'}, inplace = True)
daily_accumulation_

import matplotlib.dates as mdates
# plot the daily average, min, max, std
plt.figure(figsize=(20, 6))
plt.plot(daily_accumulation_['date_begins'], daily_accumulation_['daily_accumulation'], label='daily_accumulation')
plt.xlabel('Date')
plt.ylabel('Actual Load (MW)')
plt.title('Daily Load Before Replacing Outliers')
plt.legend()

# Set date format on x-axis
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  # set to show every 3 months
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.show()

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Apply the season function to the DataFrame
df['season'] = df['month'].apply(get_season)

# %%
# Function to replace outliers within each season
def replace_outliers_with_avg_seasonal(df):
    df['gross_load_replaced'] = df['gross_load']
    for season in df['season'].unique():
        season_data = df[df['season'] == season]['gross_load']
        lower_bound = season_data.quantile(0.01)
        upper_bound = season_data.quantile(0.99)
        print(f'{season} - Lower bound: {lower_bound:.2f}, Upper bound: {upper_bound:.2f}')
        
        outliers = (df['gross_load'] < lower_bound) | (df['gross_load'] > upper_bound) | (df['gross_load'] == 0) | (df['gross_load'] == np.nan) 
        print(f'Number of outliers in {season}: {outliers.sum()}\n')
        # Remove continuous zeros or NaNs at the end
        while pd.isna(df.iloc[-1]['gross_load_replaced']) or df.iloc[-1]['gross_load_replaced'] == 0:
            df = df.iloc[:-1]

        for idx in df[outliers].index:
            if idx == 0 or idx == len(df) - 1:
                # directly drop the first and last value
                df.at[idx, 'gross_load_replaced'] = np.nan
                continue
            # Handle edge cases where previous or next value might be NaN or zero
            prev_idx = idx - 1
            next_idx = idx + 1
            while prev_idx >= 0 and (pd.isna(df.iloc[prev_idx]['gross_load_replaced']) or df.iloc[prev_idx]['gross_load_replaced'] == 0):
                prev_idx -= 1
            while next_idx < len(df) and (pd.isna(df.iloc[next_idx]['gross_load_replaced']) or df.iloc[next_idx]['gross_load_replaced'] == 0):
                next_idx += 1
            
            if prev_idx >= 0 and next_idx < len(df):
                prev_val = df.iloc[prev_idx]['gross_load_replaced']
                next_val = df.iloc[next_idx]['gross_load_replaced']
                df.at[idx, 'gross_load_replaced'] = (prev_val + next_val) / 2
            elif prev_idx >= 0:
                df.at[idx, 'gross_load_replaced'] = df.iloc[prev_idx]['gross_load_replaced']
            elif next_idx < len(df):
                df.at[idx, 'gross_load_replaced'] = df.iloc[next_idx]['gross_load_replaced']

    return df

df = replace_outliers_with_avg_seasonal(df)

plt.figure(figsize=(16, 6))
plt.plot(df['hour_begins'], df['gross_load_replaced'], label='gross_load_replaced')
plt.xlabel('Time')
plt.ylabel('gross_load (MW)')
plt.title('Total Hourly gross_load (Replaced)')
plt.legend()

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=5))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45)

plt.show()
# Out:
# Winter - Lower bound: 17.79, Upper bound: 31.45
# Number of outliers in Winter: 3648
#
# Spring - Lower bound: 13.02, Upper bound: 27.22
# Number of outliers in Spring: 3241
#
# Summer - Lower bound: 14.43, Upper bound: 33.43
# Number of outliers in Summer: 526
#
# Fall - Lower bound: 14.07, Upper bound: 29.61
# Number of outliers in Fall: 1352

# %%
# Count the number of hours per day
df['date_begins'] = df['hour_begins'].dt.date
count_per_day = df.groupby('date_begins').size().reset_index(name='counts')

# Filter dates with less than 24 hours of data
incomplete_days = count_per_day[count_per_day['counts'] < 24]['date_begins']
print(f'Length of incomplete days: {len(incomplete_days)}')
print("Incomplete days (less than 24 hours of data):")
for day in incomplete_days:
    print(day)
# Remove rows with incomplete days
df_filtered = df[~df['date_begins'].isin(incomplete_days)]
df_filtered
# Out:
# Length of incomplete days: 3
# Incomplete days (less than 24 hours of data):
# 2018-03-14
# 2019-03-14
# 2020-03-13
#        year  month  day  time  gross_load         hour_begins date_begins  \
# 0      2018      1    1     1       23.86 2018-01-01 00:00:00  2018-01-01
# 1      2018      1    1     2       23.46 2018-01-01 01:00:00  2018-01-01
# 2      2018      1    1     3       23.28 2018-01-01 02:00:00  2018-01-01
# 3      2018      1    1     4       23.07 2018-01-01 03:00:00  2018-01-01
# 4      2018      1    1     5       23.44 2018-01-01 04:00:00  2018-01-01
# ...     ...    ...  ...   ...         ...                 ...         ...
# 26299  2020     12   31    20       28.39 2020-12-31 19:00:00  2020-12-31
# 26300  2020     12   31    21       27.43 2020-12-31 20:00:00  2020-12-31
# 26301  2020     12   31    22       26.25 2020-12-31 21:00:00  2020-12-31
# 26302  2020     12   31    23       25.18 2020-12-31 22:00:00  2020-12-31
# 26303  2020     12   31    24       24.23 2020-12-31 23:00:00  2020-12-31
#
#        season  gross_load_replaced
# 0      Winter                23.86
# 1      Winter                23.46
# 2      Winter                23.28
# 3      Winter                23.07
# 4      Winter                23.44
# ...       ...                  ...
# 26299  Winter                27.75
# 26300  Winter                27.00
# 26301  Winter                26.25
# 26302  Winter                25.18
# 26303  Winter                24.23
#
# [26235 rows x 9 columns]

# %%
df_filtered = df_filtered.dropna()
# calculate the daily accumulation of the load (gross_load_replaced)
daily_accumulation = df_filtered.groupby('date_begins')['gross_load_replaced'].sum().reset_index()
daily_accumulation.rename(columns = {'gross_load_replaced': 'daily_accumulation'}, inplace = True)
daily_accumulation
# Out:
#      date_begins  daily_accumulation
# 0     2018-01-01          574.341250
# 1     2018-01-02          620.036562
# 2     2018-01-03          631.495625
# 3     2018-01-04          627.024375
# 4     2018-01-05          624.305625
# ...          ...                 ...
# 1088  2020-12-27          539.900000
# 1089  2020-12-28          566.045000
# 1090  2020-12-29          588.632500
# 1091  2020-12-30          581.355000
# 1092  2020-12-31          612.960000
#
# [1093 rows x 2 columns]

# %%
import matplotlib.dates as mdates
# plot the daily average, min, max, std
plt.figure(figsize=(20, 6))
plt.plot(daily_accumulation['date_begins'], daily_accumulation['daily_accumulation'], label='daily_accumulation')
plt.xlabel('Date')
plt.ylabel('Actual Load (MW)')
plt.title('Daily Load After Replacing Outliers')
plt.legend()

# Set date format on x-axis
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  # set to show every 3 months
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2.2. feature engineering

# %%
# day of the week, month, year, season vairables
daily_accumulation['date_begins'] = pd.to_datetime(daily_accumulation['date_begins'])
daily_accumulation['day'] = daily_accumulation['date_begins'].dt.day
daily_accumulation['day_of_week'] = daily_accumulation['date_begins'].dt.dayofweek
daily_accumulation['month'] = daily_accumulation['date_begins'].dt.month
daily_accumulation['year'] = daily_accumulation['date_begins'].dt.year
daily_accumulation['seasons'] = (daily_accumulation['month']%12 + 3)//3
seasons = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
daily_accumulation['seasons'] = daily_accumulation['seasons'].map(seasons)

# %%
daily_accumulation['month_sin'] = np.sin((daily_accumulation['month'] - 1) * (2. * np.pi / 12))
daily_accumulation['month_cos'] = np.cos((daily_accumulation['month'] - 1) * (2. * np.pi / 12))
daily_accumulation['dow_sin'] = np.sin(daily_accumulation['day_of_week'] * (2. * np.pi / 7))
daily_accumulation['dow_cos'] = np.cos(daily_accumulation['day_of_week'] * (2. * np.pi / 7))

# %%
# holiday - 0/1 binary
us_holidays = holidays.US()
daily_accumulation['holiday'] = daily_accumulation['date_begins'].apply(lambda x: 1 if x in us_holidays else 0)

# %%
daily_accumulation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_begins         1093 non-null   datetime64[ns]
#  1   daily_accumulation  1093 non-null   float64
#  2   day                 1093 non-null   int32
#  3   day_of_week         1093 non-null   int32
#  4   month               1093 non-null   int32
#  5   year                1093 non-null   int32
#  6   seasons             1093 non-null   object
#  7   month_sin           1093 non-null   float64
#  8   month_cos           1093 non-null   float64
#  9   dow_sin             1093 non-null   float64
#  10  dow_cos             1093 non-null   float64
#  11  holiday             1093 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(1), object(1)
# memory usage: 85.5+ KB

# %%
daily_accumulation
# Out:
#      date_begins  daily_accumulation  day  day_of_week  month  year seasons  \
# 0     2018-01-01          574.341250    1            0      1  2018  Winter
# 1     2018-01-02          620.036562    2            1      1  2018  Winter
# 2     2018-01-03          631.495625    3            2      1  2018  Winter
# 3     2018-01-04          627.024375    4            3      1  2018  Winter
# 4     2018-01-05          624.305625    5            4      1  2018  Winter
# ...          ...                 ...  ...          ...    ...   ...     ...
# 1088  2020-12-27          539.900000   27            6     12  2020  Winter
# 1089  2020-12-28          566.045000   28            0     12  2020  Winter
# 1090  2020-12-29          588.632500   29            1     12  2020  Winter
# 1091  2020-12-30          581.355000   30            2     12  2020  Winter
# 1092  2020-12-31          612.960000   31            3     12  2020  Winter
#
#       month_sin  month_cos   dow_sin   dow_cos  holiday
# 0           0.0   1.000000  0.000000  1.000000        1
# 1           0.0   1.000000  0.781831  0.623490        0
# 2           0.0   1.000000  0.974928 -0.222521        0
# 3           0.0   1.000000  0.433884 -0.900969        0
# 4           0.0   1.000000 -0.433884 -0.900969        0
# ...         ...        ...       ...       ...      ...
# 1088       -0.5   0.866025 -0.781831  0.623490        0
# 1089       -0.5   0.866025  0.000000  1.000000        0
# 1090       -0.5   0.866025  0.781831  0.623490        0
# 1091       -0.5   0.866025  0.974928 -0.222521        0
# 1092       -0.5   0.866025  0.433884 -0.900969        0
#
# [1093 rows x 12 columns]

# %%
# print out the numerical and categorical features
numerical_features = daily_accumulation.select_dtypes(include=['float64']).columns.tolist()
categorical_features = daily_accumulation.select_dtypes(include=['datetime64[ns]', 'object', 'bool','int32','int64']).columns.tolist()
target = 'daily_accumulation'
numerical_features.remove(target)
print(f'Target variable: {target}')
print(f'Numerical features: {numerical_features}')
print(f'Categorical features: {categorical_features}')

# put categorical features first, numerical features last
daily_accumulation = daily_accumulation[categorical_features + numerical_features + [target]]
daily_accumulation
# Out:
# Target variable: daily_accumulation
# Numerical features: ['month_sin', 'month_cos', 'dow_sin', 'dow_cos']
# Categorical features: ['date_begins', 'day', 'day_of_week', 'month', 'year', 'seasons', 'holiday']
#      date_begins  day  day_of_week  month  year seasons  holiday  month_sin  \
# 0     2018-01-01    1            0      1  2018  Winter        1        0.0
# 1     2018-01-02    2            1      1  2018  Winter        0        0.0
# 2     2018-01-03    3            2      1  2018  Winter        0        0.0
# 3     2018-01-04    4            3      1  2018  Winter        0        0.0
# 4     2018-01-05    5            4      1  2018  Winter        0        0.0
# ...          ...  ...          ...    ...   ...     ...      ...        ...
# 1088  2020-12-27   27            6     12  2020  Winter        0       -0.5
# 1089  2020-12-28   28            0     12  2020  Winter        0       -0.5
# 1090  2020-12-29   29            1     12  2020  Winter        0       -0.5
# 1091  2020-12-30   30            2     12  2020  Winter        0       -0.5
# 1092  2020-12-31   31            3     12  2020  Winter        0       -0.5
#
#       month_cos   dow_sin   dow_cos  daily_accumulation
# 0      1.000000  0.000000  1.000000          574.341250
# 1      1.000000  0.781831  0.623490          620.036562
# 2      1.000000  0.974928 -0.222521          631.495625
# 3      1.000000  0.433884 -0.900969          627.024375
# 4      1.000000 -0.433884 -0.900969          624.305625
# ...         ...       ...       ...                 ...
# 1088   0.866025 -0.781831  0.623490          539.900000
# 1089   0.866025  0.000000  1.000000          566.045000
# 1090   0.866025  0.781831  0.623490          588.632500
# 1091   0.866025  0.974928 -0.222521          581.355000
# 1092   0.866025  0.433884 -0.900969          612.960000
#
# [1093 rows x 12 columns]

# %%
daily_accumulation.columns
# Out:
# Index(['date_begins', 'day', 'day_of_week', 'month', 'year', 'seasons',
#        'holiday', 'month_sin', 'month_cos', 'dow_sin', 'dow_cos',
#        'daily_accumulation'],
#       dtype='object')

# %% [markdown]
# ##  2.3. scaling and encoding

# %%
# encoding the categorical features - season only at the second column of values
daily_accumulation = pd.get_dummies(daily_accumulation, columns=['seasons'], drop_first=True) # at the last 3 columns
# Convert boolean columns to integers
for col in daily_accumulation.columns:
    if daily_accumulation[col].dtype == 'bool':
        daily_accumulation[col] = daily_accumulation[col].astype(int)
# place the target variable at the last column
daily_accumulation = daily_accumulation[[c for c in daily_accumulation if c not in ['daily_accumulation']] + ['daily_accumulation']]

# %%
# scaling the columns except for the 1 column
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
daily_accumulation.iloc[:, 1:] = scaler.fit_transform(daily_accumulation.iloc[:, 1:])
daily_accumulation
# Out:
#      date_begins       day  day_of_week  month  year  holiday  month_sin  \
# 0     2018-01-01  0.000000     0.000000    0.0   0.0        1       0.50
# 1     2018-01-02  0.033333     0.166667    0.0   0.0        0       0.50
# 2     2018-01-03  0.066667     0.333333    0.0   0.0        0       0.50
# 3     2018-01-04  0.100000     0.500000    0.0   0.0        0       0.50
# 4     2018-01-05  0.133333     0.666667    0.0   0.0        0       0.50
# ...          ...       ...          ...    ...   ...      ...        ...
# 1088  2020-12-27  0.866667     1.000000    1.0   1.0        0       0.25
# 1089  2020-12-28  0.900000     0.000000    1.0   1.0        0       0.25
# 1090  2020-12-29  0.933333     0.166667    1.0   1.0        0       0.25
# 1091  2020-12-30  0.966667     0.333333    1.0   1.0        0       0.25
# 1092  2020-12-31  1.000000     0.500000    1.0   1.0        0       0.25
#
#       month_cos   dow_sin       dow_cos  seasons_Spring  seasons_Summer  \
# 0      1.000000  0.500000  1.000000e+00               0               0
# 1      1.000000  0.900969  8.019377e-01               0               0
# 2      1.000000  1.000000  3.568959e-01               0               0
# 3      1.000000  0.722521  5.551115e-17               0               0
# 4      1.000000  0.277479  0.000000e+00               0               0
# ...         ...       ...           ...             ...             ...
# 1088   0.933013  0.099031  8.019377e-01               0               0
# 1089   0.933013  0.500000  1.000000e+00               0               0
# 1090   0.933013  0.900969  8.019377e-01               0               0
# 1091   0.933013  1.000000  3.568959e-01               0               0
# 1092   0.933013  0.722521  5.551115e-17               0               0
#
#       seasons_Winter  daily_accumulation
# 0                  1            0.595353
# 1                  1            0.726619
# 2                  1            0.759537
# 3                  1            0.746693
# 4                  1            0.738883
# ...              ...                 ...
# 1088               1            0.496415
# 1089               1            0.571520
# 1090               1            0.636406
# 1091               1            0.615501
# 1092               1            0.706291
#
# [1093 rows x 14 columns]

# %%
# save the values of column gross_load_replaced, drop it and the attach at the last column 
gross_load_replaced = daily_accumulation['daily_accumulation']
daily_accumulation.drop(columns='daily_accumulation', inplace=True)
daily_accumulation['daily_accumulation'] = gross_load_replaced
daily_accumulation
# Out:
#      date_begins       day  day_of_week  month  year  holiday  month_sin  \
# 0     2018-01-01  0.000000     0.000000    0.0   0.0        1       0.50
# 1     2018-01-02  0.033333     0.166667    0.0   0.0        0       0.50
# 2     2018-01-03  0.066667     0.333333    0.0   0.0        0       0.50
# 3     2018-01-04  0.100000     0.500000    0.0   0.0        0       0.50
# 4     2018-01-05  0.133333     0.666667    0.0   0.0        0       0.50
# ...          ...       ...          ...    ...   ...      ...        ...
# 1088  2020-12-27  0.866667     1.000000    1.0   1.0        0       0.25
# 1089  2020-12-28  0.900000     0.000000    1.0   1.0        0       0.25
# 1090  2020-12-29  0.933333     0.166667    1.0   1.0        0       0.25
# 1091  2020-12-30  0.966667     0.333333    1.0   1.0        0       0.25
# 1092  2020-12-31  1.000000     0.500000    1.0   1.0        0       0.25
#
#       month_cos   dow_sin       dow_cos  seasons_Spring  seasons_Summer  \
# 0      1.000000  0.500000  1.000000e+00               0               0
# 1      1.000000  0.900969  8.019377e-01               0               0
# 2      1.000000  1.000000  3.568959e-01               0               0
# 3      1.000000  0.722521  5.551115e-17               0               0
# 4      1.000000  0.277479  0.000000e+00               0               0
# ...         ...       ...           ...             ...             ...
# 1088   0.933013  0.099031  8.019377e-01               0               0
# 1089   0.933013  0.500000  1.000000e+00               0               0
# 1090   0.933013  0.900969  8.019377e-01               0               0
# 1091   0.933013  1.000000  3.568959e-01               0               0
# 1092   0.933013  0.722521  5.551115e-17               0               0
#
#       seasons_Winter  daily_accumulation
# 0                  1            0.595353
# 1                  1            0.726619
# 2                  1            0.759537
# 3                  1            0.746693
# 4                  1            0.738883
# ...              ...                 ...
# 1088               1            0.496415
# 1089               1            0.571520
# 1090               1            0.636406
# 1091               1            0.615501
# 1092               1            0.706291
#
# [1093 rows x 14 columns]

# %%
daily_accumulation = daily_accumulation.dropna()
daily_accumulation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_begins         1093 non-null   datetime64[ns]
#  1   day                 1093 non-null   float64
#  2   day_of_week         1093 non-null   float64
#  3   month               1093 non-null   float64
#  4   year                1093 non-null   float64
#  5   holiday             1093 non-null   int64
#  6   month_sin           1093 non-null   float64
#  7   month_cos           1093 non-null   float64
#  8   dow_sin             1093 non-null   float64
#  9   dow_cos             1093 non-null   float64
#  10  seasons_Spring      1093 non-null   int32
#  11  seasons_Summer      1093 non-null   int32
#  12  seasons_Winter      1093 non-null   int32
#  13  daily_accumulation  1093 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int32(3), int64(1)
# memory usage: 106.9 KB

# %% [markdown]
# ## 2.4. dividing the data into training and testing

# %%
years_of_data = len(daily_accumulation) / 365
print(f'Total years of data: {years_of_data}')
# total number of days for training and testing
print(f'Total number of days for training: {daily_accumulation.shape[0]}')
# Out:
# Total years of data: 2.9945205479452053
# Total number of days for training: 1093

# %%
daily_accumulation = daily_accumulation.sort_values(by='date_begins')
values = daily_accumulation.drop(columns='date_begins').values
dates = daily_accumulation['date_begins']

# out of sample data: total length multiplies 0.3
train_days = int(values.shape[0] * 0.7)
# in sample data: the rest of the data
train = values[:train_days, :]
train_timestamps = dates[:train_days]
# print(f'start date of in sample data: {train["date"].min()}')
# print(f'end date of in sample data: {train["date"].max()}')
# print(f'length of in sample data: {train.
# shape[0]}\n')

print(f'min: {train_timestamps.min()}')
print(f'max: {train_timestamps.max()}')
print(f'length of in sample data: {train.shape[0]}\n')

test = values[train_days:, : ]
test_timestamps = dates[train_days:]
# print(f'start date of out of sample data: {test["date"].min()}')
# print(f'end date of out of sample data: {test["date"].max()}')
# print(f'length of out of sample data: {test.shape[0]}\n')

print(f'min: {test_timestamps.min()}')
print(f'max: {test_timestamps.max()}')
print(f'length of out of sample data: {test.shape[0]}')
# Out:
# min: 2018-01-01 00:00:00
# max: 2020-02-06 00:00:00
# length of in sample data: 765
#
# min: 2020-02-07 00:00:00
# max: 2020-12-31 00:00:00
# length of out of sample data: 328

# %%
# dividing the data into x and y
# x: All columns except the last,  y: The last column
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (765, 1, 12) (765,) (328, 1, 12) (328,)

# %% [markdown]
# ## 2.5. fitting the model

# %%
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM, Dropout, Dense, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.35))
model.add(Dense(1, kernel_regularizer=l2(0.001)))

# Set the initial learning rate to a lower value
initial_learning_rate = 0.005
optimizer = Adam(learning_rate=initial_learning_rate)
model.compile(loss='mae', optimizer=optimizer, metrics=['mae', 'mse', 'mape'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6)

# Fit the network
history = model.fit(train_X, train_y, epochs=200, batch_size=64, validation_data=(test_X, test_y),
                    verbose=2, shuffle=False,callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/200
# 12/12 - 1s - 72ms/step - loss: 0.2949 - mae: 0.2930 - mape: 58.0385 - mse: 0.1296 - val_loss: 0.2167 - val_mae: 0.2147 - val_mape: 2019242.5000 - val_mse: 0.0708 - learning_rate: 0.0050
# Epoch 2/200
# 12/12 - 0s - 3ms/step - loss: 0.1598 - mae: 0.1580 - mape: 40.9609 - mse: 0.0390 - val_loss: 0.1287 - val_mae: 0.1270 - val_mape: 1237226.5000 - val_mse: 0.0237 - learning_rate: 0.0050
# Epoch 3/200
# 12/12 - 0s - 3ms/step - loss: 0.1323 - mae: 0.1306 - mape: 29.0650 - mse: 0.0266 - val_loss: 0.1288 - val_mae: 0.1272 - val_mape: 1223539.7500 - val_mse: 0.0245 - learning_rate: 0.0050
# Epoch 4/200
# 12/12 - 0s - 3ms/step - loss: 0.1178 - mae: 0.1161 - mape: 27.9626 - mse: 0.0209 - val_loss: 0.1068 - val_mae: 0.1052 - val_mape: 937232.1250 - val_mse: 0.0165 - learning_rate: 0.0050
# Epoch 5/200
# 12/12 - 0s - 3ms/step - loss: 0.1106 - mae: 0.1090 - mape: 24.0794 - mse: 0.0186 - val_loss: 0.1081 - val_mae: 0.1064 - val_mape: 903006.3125 - val_mse: 0.0166 - learning_rate: 0.0050
# Epoch 6/200
# 12/12 - 0s - 3ms/step - loss: 0.1056 - mae: 0.1040 - mape: 23.9749 - mse: 0.0172 - val_loss: 0.0983 - val_mae: 0.0967 - val_mape: 769347.6250 - val_mse: 0.0141 - learning_rate: 0.0050
# Epoch 7/200
# 12/12 - 0s - 3ms/step - loss: 0.1035 - mae: 0.1019 - mape: 23.4232 - mse: 0.0164 - val_loss: 0.0981 - val_mae: 0.0965 - val_mape: 750659.8750 - val_mse: 0.0141 - learning_rate: 0.0050
# Epoch 8/200
# 12/12 - 0s - 3ms/step - loss: 0.1016 - mae: 0.0999 - mape: 22.5214 - mse: 0.0157 - val_loss: 0.0961 - val_mae: 0.0945 - val_mape: 721998.6875 - val_mse: 0.0137 - learning_rate: 0.0050
# Epoch 9/200
# 12/12 - 0s - 3ms/step - loss: 0.0983 - mae: 0.0967 - mape: 22.6147 - mse: 0.0150 - val_loss: 0.0941 - val_mae: 0.0925 - val_mape: 672556.2500 - val_mse: 0.0131 - learning_rate: 0.0050
# Epoch 10/200
# 12/12 - 0s - 3ms/step - loss: 0.0963 - mae: 0.0948 - mape: 21.5941 - mse: 0.0142 - val_loss: 0.0966 - val_mae: 0.0950 - val_mape: 711112.1250 - val_mse: 0.0139 - learning_rate: 0.0050
# Epoch 11/200
# 12/12 - 0s - 3ms/step - loss: 0.0926 - mae: 0.0910 - mape: 20.5736 - mse: 0.0133 - val_loss: 0.0936 - val_mae: 0.0921 - val_mape: 662450.3125 - val_mse: 0.0128 - learning_rate: 0.0050
# Epoch 12/200
# 12/12 - 0s - 4ms/step - loss: 0.0900 - mae: 0.0884 - mape: 20.1788 - mse: 0.0124 - val_loss: 0.0911 - val_mae: 0.0896 - val_mape: 607053.2500 - val_mse: 0.0122 - learning_rate: 0.0050
# Epoch 13/200
# 12/12 - 0s - 3ms/step - loss: 0.0942 - mae: 0.0927 - mape: 21.5027 - mse: 0.0136 - val_loss: 0.0965 - val_mae: 0.0950 - val_mape: 672717.9375 - val_mse: 0.0135 - learning_rate: 0.0050
# Epoch 14/200
# 12/12 - 0s - 3ms/step - loss: 0.0899 - mae: 0.0884 - mape: 19.9412 - mse: 0.0125 - val_loss: 0.0900 - val_mae: 0.0885 - val_mape: 575188.7500 - val_mse: 0.0119 - learning_rate: 0.0050
# Epoch 15/200
# 12/12 - 0s - 3ms/step - loss: 0.0900 - mae: 0.0885 - mape: 20.3216 - mse: 0.0123 - val_loss: 0.0900 - val_mae: 0.0884 - val_mape: 560189.6875 - val_mse: 0.0118 - learning_rate: 0.0050
# Epoch 16/200
# 12/12 - 0s - 3ms/step - loss: 0.0902 - mae: 0.0887 - mape: 19.6586 - mse: 0.0127 - val_loss: 0.0890 - val_mae: 0.0875 - val_mape: 533728.1250 - val_mse: 0.0116 - learning_rate: 0.0050
# Epoch 17/200
# 12/12 - 0s - 3ms/step - loss: 0.0883 - mae: 0.0868 - mape: 19.4135 - mse: 0.0120 - val_loss: 0.0899 - val_mae: 0.0884 - val_mape: 543635.6250 - val_mse: 0.0117 - learning_rate: 0.0050
# Epoch 18/200
# 12/12 - 0s - 3ms/step - loss: 0.0873 - mae: 0.0858 - mape: 19.2481 - mse: 0.0120 - val_loss: 0.0873 - val_mae: 0.0858 - val_mape: 470369.1250 - val_mse: 0.0111 - learning_rate: 0.0050
# Epoch 19/200
# 12/12 - 0s - 3ms/step - loss: 0.0843 - mae: 0.0828 - mape: 18.8989 - mse: 0.0112 - val_loss: 0.0870 - val_mae: 0.0855 - val_mape: 447158.3750 - val_mse: 0.0110 - learning_rate: 0.0050
# Epoch 20/200
# 12/12 - 0s - 3ms/step - loss: 0.0887 - mae: 0.0872 - mape: 19.2938 - mse: 0.0119 - val_loss: 0.0868 - val_mae: 0.0853 - val_mape: 461691.1562 - val_mse: 0.0109 - learning_rate: 0.0050
# Epoch 21/200
# 12/12 - 0s - 3ms/step - loss: 0.0836 - mae: 0.0820 - mape: 18.3916 - mse: 0.0110 - val_loss: 0.0868 - val_mae: 0.0853 - val_mape: 446068.2500 - val_mse: 0.0111 - learning_rate: 0.0050
# Epoch 22/200
# 12/12 - 0s - 3ms/step - loss: 0.0847 - mae: 0.0832 - mape: 18.9104 - mse: 0.0110 - val_loss: 0.0895 - val_mae: 0.0880 - val_mape: 467090.2500 - val_mse: 0.0115 - learning_rate: 0.0050
# Epoch 23/200
# 12/12 - 0s - 3ms/step - loss: 0.0844 - mae: 0.0829 - mape: 18.4546 - mse: 0.0114 - val_loss: 0.0859 - val_mae: 0.0844 - val_mape: 412831.6250 - val_mse: 0.0107 - learning_rate: 0.0050
# Epoch 24/200
# 12/12 - 0s - 3ms/step - loss: 0.0834 - mae: 0.0820 - mape: 18.6448 - mse: 0.0107 - val_loss: 0.0868 - val_mae: 0.0854 - val_mape: 427137.6562 - val_mse: 0.0109 - learning_rate: 0.0050
# Epoch 25/200
# 12/12 - 0s - 3ms/step - loss: 0.0840 - mae: 0.0825 - mape: 18.7081 - mse: 0.0110 - val_loss: 0.0851 - val_mae: 0.0836 - val_mape: 378557.7188 - val_mse: 0.0106 - learning_rate: 0.0050
# Epoch 26/200
# 12/12 - 0s - 3ms/step - loss: 0.0835 - mae: 0.0821 - mape: 18.1214 - mse: 0.0108 - val_loss: 0.0868 - val_mae: 0.0853 - val_mape: 426440.3750 - val_mse: 0.0109 - learning_rate: 0.0050
# Epoch 27/200
# 12/12 - 0s - 3ms/step - loss: 0.0834 - mae: 0.0820 - mape: 18.4311 - mse: 0.0109 - val_loss: 0.0878 - val_mae: 0.0864 - val_mape: 445158.0000 - val_mse: 0.0110 - learning_rate: 0.0050
# Epoch 28/200
# 12/12 - 0s - 3ms/step - loss: 0.0800 - mae: 0.0786 - mape: 17.5624 - mse: 0.0100 - val_loss: 0.0844 - val_mae: 0.0830 - val_mape: 368068.4375 - val_mse: 0.0103 - learning_rate: 0.0050
# Epoch 29/200
# 12/12 - 0s - 3ms/step - loss: 0.0833 - mae: 0.0820 - mape: 18.6793 - mse: 0.0109 - val_loss: 0.0831 - val_mae: 0.0817 - val_mape: 319708.6250 - val_mse: 0.0102 - learning_rate: 0.0050
# Epoch 30/200
# 12/12 - 0s - 3ms/step - loss: 0.0826 - mae: 0.0812 - mape: 18.1772 - mse: 0.0105 - val_loss: 0.0844 - val_mae: 0.0831 - val_mape: 352362.1250 - val_mse: 0.0104 - learning_rate: 0.0050
# Epoch 31/200
# 12/12 - 0s - 3ms/step - loss: 0.0798 - mae: 0.0784 - mape: 17.7514 - mse: 0.0100 - val_loss: 0.0847 - val_mae: 0.0833 - val_mape: 346945.2812 - val_mse: 0.0106 - learning_rate: 0.0050
# Epoch 32/200
# 12/12 - 0s - 3ms/step - loss: 0.0834 - mae: 0.0820 - mape: 17.4974 - mse: 0.0110 - val_loss: 0.0824 - val_mae: 0.0810 - val_mape: 300391.6250 - val_mse: 0.0101 - learning_rate: 0.0050
# Epoch 33/200
# 12/12 - 0s - 3ms/step - loss: 0.0797 - mae: 0.0783 - mape: 17.3727 - mse: 0.0102 - val_loss: 0.0817 - val_mae: 0.0804 - val_mape: 302762.7188 - val_mse: 0.0100 - learning_rate: 0.0050
# Epoch 34/200
# 12/12 - 0s - 3ms/step - loss: 0.0822 - mae: 0.0809 - mape: 18.4168 - mse: 0.0105 - val_loss: 0.0829 - val_mae: 0.0816 - val_mape: 323195.5000 - val_mse: 0.0100 - learning_rate: 0.0050
# Epoch 35/200
# 12/12 - 0s - 3ms/step - loss: 0.0784 - mae: 0.0771 - mape: 17.6729 - mse: 0.0098 - val_loss: 0.0825 - val_mae: 0.0812 - val_mape: 289309.9062 - val_mse: 0.0101 - learning_rate: 0.0050
# Epoch 36/200
# 12/12 - 0s - 3ms/step - loss: 0.0797 - mae: 0.0784 - mape: 17.5324 - mse: 0.0099 - val_loss: 0.0812 - val_mae: 0.0799 - val_mape: 226496.4844 - val_mse: 0.0099 - learning_rate: 0.0050
# Epoch 37/200
# 12/12 - 0s - 3ms/step - loss: 0.0814 - mae: 0.0801 - mape: 17.4740 - mse: 0.0103 - val_loss: 0.0834 - val_mae: 0.0821 - val_mape: 308560.2812 - val_mse: 0.0102 - learning_rate: 0.0050
# Epoch 38/200
# 12/12 - 0s - 3ms/step - loss: 0.0778 - mae: 0.0766 - mape: 16.9968 - mse: 0.0099 - val_loss: 0.0816 - val_mae: 0.0804 - val_mape: 295046.7500 - val_mse: 0.0097 - learning_rate: 0.0050
# Epoch 39/200
# 12/12 - 0s - 3ms/step - loss: 0.0791 - mae: 0.0778 - mape: 17.9172 - mse: 0.0096 - val_loss: 0.0815 - val_mae: 0.0803 - val_mape: 286938.6875 - val_mse: 0.0097 - learning_rate: 0.0050
# Epoch 40/200
# 12/12 - 0s - 3ms/step - loss: 0.0801 - mae: 0.0789 - mape: 17.3718 - mse: 0.0102 - val_loss: 0.0800 - val_mae: 0.0787 - val_mape: 208682.4688 - val_mse: 0.0096 - learning_rate: 0.0050
# Epoch 41/200
# 12/12 - 0s - 3ms/step - loss: 0.0786 - mae: 0.0773 - mape: 17.2146 - mse: 0.0096 - val_loss: 0.0829 - val_mae: 0.0816 - val_mape: 267464.8750 - val_mse: 0.0102 - learning_rate: 0.0050
# Epoch 42/200
# 12/12 - 0s - 3ms/step - loss: 0.0806 - mae: 0.0794 - mape: 17.1090 - mse: 0.0105 - val_loss: 0.0835 - val_mae: 0.0823 - val_mape: 271620.0000 - val_mse: 0.0103 - learning_rate: 0.0050
# Epoch 43/200
# 12/12 - 0s - 3ms/step - loss: 0.0783 - mae: 0.0771 - mape: 17.0434 - mse: 0.0098 - val_loss: 0.0820 - val_mae: 0.0808 - val_mape: 236661.6094 - val_mse: 0.0099 - learning_rate: 0.0050
# Epoch 44/200
# 12/12 - 0s - 3ms/step - loss: 0.0767 - mae: 0.0755 - mape: 17.0157 - mse: 0.0094 - val_loss: 0.0803 - val_mae: 0.0791 - val_mape: 197546.7500 - val_mse: 0.0096 - learning_rate: 0.0050
# Epoch 45/200
# 12/12 - 0s - 3ms/step - loss: 0.0779 - mae: 0.0767 - mape: 16.8314 - mse: 0.0096 - val_loss: 0.0809 - val_mae: 0.0798 - val_mape: 238696.2969 - val_mse: 0.0097 - learning_rate: 0.0050
# Epoch 46/200
# 12/12 - 0s - 3ms/step - loss: 0.0774 - mae: 0.0762 - mape: 16.6738 - mse: 0.0095 - val_loss: 0.0806 - val_mae: 0.0794 - val_mape: 235789.6875 - val_mse: 0.0096 - learning_rate: 0.0050
# Epoch 47/200
# 12/12 - 0s - 3ms/step - loss: 0.0769 - mae: 0.0757 - mape: 16.6342 - mse: 0.0097 - val_loss: 0.0795 - val_mae: 0.0783 - val_mape: 200262.6719 - val_mse: 0.0094 - learning_rate: 0.0050
# Epoch 48/200
# 12/12 - 0s - 3ms/step - loss: 0.0773 - mae: 0.0761 - mape: 16.4550 - mse: 0.0096 - val_loss: 0.0808 - val_mae: 0.0796 - val_mape: 222958.9062 - val_mse: 0.0096 - learning_rate: 0.0050
# Epoch 49/200
# 12/12 - 0s - 3ms/step - loss: 0.0747 - mae: 0.0736 - mape: 16.5496 - mse: 0.0090 - val_loss: 0.0796 - val_mae: 0.0785 - val_mape: 188558.7656 - val_mse: 0.0094 - learning_rate: 0.0050
# Epoch 50/200
# 12/12 - 0s - 3ms/step - loss: 0.0754 - mae: 0.0743 - mape: 16.5996 - mse: 0.0090 - val_loss: 0.0783 - val_mae: 0.0771 - val_mape: 175105.6719 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 51/200
# 12/12 - 0s - 3ms/step - loss: 0.0782 - mae: 0.0771 - mape: 16.8521 - mse: 0.0097 - val_loss: 0.0795 - val_mae: 0.0784 - val_mape: 225276.9688 - val_mse: 0.0093 - learning_rate: 0.0050
# Epoch 52/200
# 12/12 - 0s - 3ms/step - loss: 0.0771 - mae: 0.0760 - mape: 16.8874 - mse: 0.0094 - val_loss: 0.0791 - val_mae: 0.0780 - val_mape: 195379.9219 - val_mse: 0.0092 - learning_rate: 0.0050
# Epoch 53/200
# 12/12 - 0s - 3ms/step - loss: 0.0748 - mae: 0.0737 - mape: 16.4186 - mse: 0.0088 - val_loss: 0.0784 - val_mae: 0.0773 - val_mape: 174903.7969 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 54/200
# 12/12 - 0s - 3ms/step - loss: 0.0756 - mae: 0.0745 - mape: 16.2787 - mse: 0.0093 - val_loss: 0.0790 - val_mae: 0.0780 - val_mape: 212071.4688 - val_mse: 0.0092 - learning_rate: 0.0050
# Epoch 55/200
# 12/12 - 0s - 3ms/step - loss: 0.0745 - mae: 0.0734 - mape: 16.3616 - mse: 0.0090 - val_loss: 0.0794 - val_mae: 0.0784 - val_mape: 204287.0781 - val_mse: 0.0093 - learning_rate: 0.0050
# Epoch 56/200
# 12/12 - 0s - 3ms/step - loss: 0.0747 - mae: 0.0737 - mape: 16.5211 - mse: 0.0090 - val_loss: 0.0775 - val_mae: 0.0765 - val_mape: 107184.9531 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 57/200
# 12/12 - 0s - 5ms/step - loss: 0.0758 - mae: 0.0748 - mape: 16.7184 - mse: 0.0090 - val_loss: 0.0780 - val_mae: 0.0770 - val_mape: 111464.7578 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 58/200
# 12/12 - 0s - 3ms/step - loss: 0.0749 - mae: 0.0739 - mape: 16.7121 - mse: 0.0091 - val_loss: 0.0771 - val_mae: 0.0761 - val_mape: 120502.6094 - val_mse: 0.0089 - learning_rate: 0.0050
# Epoch 59/200
# 12/12 - 0s - 3ms/step - loss: 0.0776 - mae: 0.0766 - mape: 16.6994 - mse: 0.0098 - val_loss: 0.0795 - val_mae: 0.0785 - val_mape: 219189.9688 - val_mse: 0.0093 - learning_rate: 0.0050
# Epoch 60/200
# 12/12 - 0s - 3ms/step - loss: 0.0765 - mae: 0.0756 - mape: 16.6948 - mse: 0.0096 - val_loss: 0.0794 - val_mae: 0.0785 - val_mape: 185739.7188 - val_mse: 0.0094 - learning_rate: 0.0050
# Epoch 61/200
# 12/12 - 0s - 3ms/step - loss: 0.0762 - mae: 0.0752 - mape: 16.9195 - mse: 0.0093 - val_loss: 0.0771 - val_mae: 0.0761 - val_mape: 89972.8281 - val_mse: 0.0089 - learning_rate: 0.0050
# Epoch 62/200
# 12/12 - 0s - 3ms/step - loss: 0.0744 - mae: 0.0734 - mape: 16.1343 - mse: 0.0087 - val_loss: 0.0785 - val_mae: 0.0774 - val_mape: 168557.8594 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 63/200
# 12/12 - 0s - 3ms/step - loss: 0.0778 - mae: 0.0768 - mape: 16.7890 - mse: 0.0096 - val_loss: 0.0789 - val_mae: 0.0779 - val_mape: 158191.2656 - val_mse: 0.0092 - learning_rate: 0.0050
# Epoch 64/200
# 12/12 - 0s - 3ms/step - loss: 0.0739 - mae: 0.0729 - mape: 15.9812 - mse: 0.0088 - val_loss: 0.0773 - val_mae: 0.0763 - val_mape: 152580.3438 - val_mse: 0.0089 - learning_rate: 0.0050
# Epoch 65/200
# 12/12 - 0s - 3ms/step - loss: 0.0727 - mae: 0.0718 - mape: 16.0932 - mse: 0.0087 - val_loss: 0.0778 - val_mae: 0.0769 - val_mape: 148794.7500 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 66/200
# 12/12 - 0s - 3ms/step - loss: 0.0735 - mae: 0.0726 - mape: 15.9575 - mse: 0.0089 - val_loss: 0.0780 - val_mae: 0.0770 - val_mape: 119763.7188 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 67/200
# 12/12 - 0s - 3ms/step - loss: 0.0737 - mae: 0.0728 - mape: 16.2487 - mse: 0.0086 - val_loss: 0.0770 - val_mae: 0.0761 - val_mape: 112250.4531 - val_mse: 0.0089 - learning_rate: 0.0050
# Epoch 68/200
# 12/12 - 0s - 3ms/step - loss: 0.0743 - mae: 0.0733 - mape: 16.3058 - mse: 0.0091 - val_loss: 0.0768 - val_mae: 0.0758 - val_mape: 173941.9219 - val_mse: 0.0088 - learning_rate: 0.0050
# Epoch 69/200
# 12/12 - 0s - 3ms/step - loss: 0.0762 - mae: 0.0753 - mape: 16.5318 - mse: 0.0093 - val_loss: 0.0778 - val_mae: 0.0769 - val_mape: 193810.0312 - val_mse: 0.0089 - learning_rate: 0.0050
# Epoch 70/200
# 12/12 - 0s - 3ms/step - loss: 0.0727 - mae: 0.0718 - mape: 16.0365 - mse: 0.0088 - val_loss: 0.0792 - val_mae: 0.0784 - val_mape: 180682.3750 - val_mse: 0.0093 - learning_rate: 0.0050
# Epoch 71/200
# 12/12 - 0s - 3ms/step - loss: 0.0735 - mae: 0.0726 - mape: 15.9610 - mse: 0.0088 - val_loss: 0.0770 - val_mae: 0.0761 - val_mape: 21220.9824 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 72/200
# 12/12 - 0s - 3ms/step - loss: 0.0729 - mae: 0.0720 - mape: 16.2009 - mse: 0.0088 - val_loss: 0.0775 - val_mae: 0.0766 - val_mape: 168356.9531 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 73/200
# 12/12 - 0s - 3ms/step - loss: 0.0752 - mae: 0.0744 - mape: 16.4489 - mse: 0.0093 - val_loss: 0.0784 - val_mae: 0.0775 - val_mape: 173325.1562 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 74/200
# 12/12 - 0s - 3ms/step - loss: 0.0729 - mae: 0.0720 - mape: 16.2066 - mse: 0.0085 - val_loss: 0.0773 - val_mae: 0.0765 - val_mape: 54469.0078 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 75/200
# 12/12 - 0s - 3ms/step - loss: 0.0734 - mae: 0.0725 - mape: 16.0585 - mse: 0.0086 - val_loss: 0.0784 - val_mae: 0.0775 - val_mape: 203933.6875 - val_mse: 0.0091 - learning_rate: 0.0050
# Epoch 76/200
# 12/12 - 0s - 3ms/step - loss: 0.0740 - mae: 0.0731 - mape: 15.9706 - mse: 0.0087 - val_loss: 0.0773 - val_mae: 0.0765 - val_mape: 162617.0781 - val_mse: 0.0088 - learning_rate: 0.0050
# Epoch 77/200
# 12/12 - 0s - 3ms/step - loss: 0.0716 - mae: 0.0707 - mape: 16.1411 - mse: 0.0084 - val_loss: 0.0759 - val_mae: 0.0750 - val_mape: 104502.9062 - val_mse: 0.0087 - learning_rate: 0.0050
# Epoch 78/200
# 12/12 - 0s - 3ms/step - loss: 0.0730 - mae: 0.0721 - mape: 15.9168 - mse: 0.0088 - val_loss: 0.0755 - val_mae: 0.0746 - val_mape: 84661.5156 - val_mse: 0.0086 - learning_rate: 0.0050
# Epoch 79/200
# 12/12 - 0s - 3ms/step - loss: 0.0727 - mae: 0.0718 - mape: 15.5767 - mse: 0.0089 - val_loss: 0.0779 - val_mae: 0.0771 - val_mape: 195579.6250 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 80/200
# 12/12 - 0s - 3ms/step - loss: 0.0724 - mae: 0.0716 - mape: 16.3201 - mse: 0.0088 - val_loss: 0.0778 - val_mae: 0.0770 - val_mape: 124282.7344 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 81/200
# 12/12 - 0s - 3ms/step - loss: 0.0723 - mae: 0.0715 - mape: 16.1081 - mse: 0.0084 - val_loss: 0.0763 - val_mae: 0.0754 - val_mape: 68670.7578 - val_mse: 0.0088 - learning_rate: 0.0050
# Epoch 82/200
# 12/12 - 0s - 3ms/step - loss: 0.0721 - mae: 0.0713 - mape: 15.8067 - mse: 0.0086 - val_loss: 0.0762 - val_mae: 0.0754 - val_mape: 24996.1699 - val_mse: 0.0088 - learning_rate: 0.0050
# Epoch 83/200
# 12/12 - 0s - 3ms/step - loss: 0.0721 - mae: 0.0713 - mape: 16.0547 - mse: 0.0086 - val_loss: 0.0770 - val_mae: 0.0762 - val_mape: 121384.6953 - val_mse: 0.0088 - learning_rate: 0.0050
# Epoch 84/200
# 12/12 - 0s - 3ms/step - loss: 0.0715 - mae: 0.0707 - mape: 15.8870 - mse: 0.0087 - val_loss: 0.0763 - val_mae: 0.0755 - val_mape: 132678.1250 - val_mse: 0.0086 - learning_rate: 0.0050
# Epoch 85/200
# 12/12 - 0s - 3ms/step - loss: 0.0714 - mae: 0.0706 - mape: 15.8002 - mse: 0.0085 - val_loss: 0.0771 - val_mae: 0.0762 - val_mape: 68032.8281 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 86/200
# 12/12 - 0s - 3ms/step - loss: 0.0720 - mae: 0.0711 - mape: 15.4980 - mse: 0.0086 - val_loss: 0.0759 - val_mae: 0.0751 - val_mape: 83089.4062 - val_mse: 0.0087 - learning_rate: 0.0050
# Epoch 87/200
# 12/12 - 0s - 3ms/step - loss: 0.0714 - mae: 0.0706 - mape: 15.4747 - mse: 0.0085 - val_loss: 0.0784 - val_mae: 0.0776 - val_mape: 213005.4844 - val_mse: 0.0090 - learning_rate: 0.0050
# Epoch 88/200
# 12/12 - 0s - 3ms/step - loss: 0.0731 - mae: 0.0723 - mape: 16.2332 - mse: 0.0088 - val_loss: 0.0783 - val_mae: 0.0775 - val_mape: 179449.4844 - val_mse: 0.0090 - learning_rate: 0.0050

# %%
# Plot history for loss, MAE, and RMSE as before
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')

plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['mae'], label='train_mae')
plt.plot(history.history['val_mae'], label='val_mae')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.title('Mean Absolute Error (MAE)')
plt.show()

train_rmse = np.sqrt(history.history['mse'])
val_rmse = np.sqrt(history.history['val_mse'])
plt.figure(figsize=(12, 6))
plt.plot(train_rmse, label='train_rmse')
plt.plot(val_rmse, label='val_rmse')
plt.xlabel('Epochs')
plt.ylabel('RMSE')
plt.legend()
plt.title('Root Mean Squared Error (RMSE)')
plt.show()

# %%
# Calculate MAPE manually, handling zero values
def safe_mape(y_true, y_pred, epsilon=1e-10):
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / (y_true[mask] + epsilon))) * 100

train_predictions = model.predict(train_X)
train_X_reshaped = train_X.reshape((train_X.shape[0], train_X.shape[2]))
# Invert scaling for forecast
inv_yhat = np.concatenate((train_X_reshaped,train_predictions), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, -1]
# Invert scaling for actual
train_y_reshaped = train_y.reshape((len(train_y), 1))
inv_y = np.concatenate((train_X_reshaped, train_y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, -1]
# Calculate RMSE, MAE, MAPE
train_rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
train_mae = mean_absolute_error(inv_y, inv_yhat)
train_mape = np.mean(np.abs((inv_y - inv_yhat) / inv_y)) * 100


test_predictions = model.predict(test_X)
# Reshape test_X for inverse scaling
test_X_reshaped = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# Invert scaling for forecast
inv_yhat = np.concatenate((test_X_reshaped,test_predictions), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, -1]
# Invert scaling for actual
test_y_reshaped = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_X_reshaped, test_y_reshaped), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, -1]
# Calculate RMSE, MAE, MAPE
test_rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
test_mae = mean_absolute_error(inv_y, inv_yhat)
test_mape = np.mean(np.abs((inv_y - inv_yhat) / inv_y)) * 100


print(f"Train RMSE: {train_rmse:.3f}")
print(f"Train MAE: {train_mae:.3f}")
print(f"Train MAPE: {train_mape:.3f}%")
print(f"\nTest RMSE: {test_rmse:.3f}")
print(f"Test MAE: {test_mae:.3f}")
print(f"Test MAPE: {test_mape:.3f}%")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# Train RMSE: 30.653
# Train MAE: 23.451
# Train MAPE: 4.337%
#
# Test RMSE: 32.285
# Test MAE: 25.984
# Test MAPE: 5.294%

# %% [markdown]
# ## 2.6. prediction plot

# %%
# Extract the test data with timestamps
test_df = daily_gross_load.iloc[train_days:, :].copy()
test_df['date'] = daily_gross_load.iloc[train_days:]['date']

# Identify gaps in the data
actual_vs_predicted = pd.DataFrame({
    'date': test_timestamps,
    'actual': inv_y,
    'predicted': inv_yhat
})

# Check for gaps in the timestamps (in days)
actual_vs_predicted['date_diff'] = actual_vs_predicted['date'].diff().dt.days
gaps = actual_vs_predicted[actual_vs_predicted['date_diff'] > 1]

# Plot actual vs predicted values with gaps highlighted
plt.figure(figsize=(20, 6))
plt.plot(actual_vs_predicted['date'], actual_vs_predicted['actual'], label='Actual', color='blue')
plt.plot(actual_vs_predicted['date'], actual_vs_predicted['predicted'], label='Predicted', color='orange')
for gap_start in gaps['date']:
    plt.axvline(x=gap_start, color='red', linestyle='--', alpha=0.5)
plt.title('Actual vs Predicted Values with Gaps Highlighted')
plt.xlabel('Time')
plt.ylabel('Values (MW)')
plt.legend()
plt.grid(True)

# Set date format on x-axis every 15 days
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=35))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.xticks(rotation=45)
plt.show()

# Print the gaps and their nearest significant time differences
print("Gaps in data:")
for index, row in gaps.iterrows():
    previous_timestamp = row['date'] - pd.Timedelta(days=row['date_diff'])
    next_timestamp = row['date'] + pd.Timedelta(days=row['date_diff'])

    previous_row = actual_vs_predicted[actual_vs_predicted['date'] == previous_timestamp]
    next_row = actual_vs_predicted[actual_vs_predicted['date'] == next_timestamp]

    gap_start = previous_row['date'].values[0] if not previous_row.empty else 'N/A'
    gap_end = row['date']

    print(f"Gap Start: {pd.to_datetime(gap_start).strftime('%Y-%m-%d') if gap_start != 'N/A' else 'N/A'}")
    print(f"Gap ends at: {gap_end.strftime('%Y-%m-%d')}")
    print(f"Time Difference: {row['date_diff']} days\n")
# Out:
# Gaps in data:
# Gap Start: 2020-03-12
# Gap ends at: 2020-03-14
# Time Difference: 2.0 days
